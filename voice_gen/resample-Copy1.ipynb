# %%
import librosa
import soundfile as sf
import os
import glob
from pathlib import Path

def resample_wav_librosa(input_path, output_path, target_sr=16000):
    """
    使用librosa将WAV文件重采样到目标采样率
    
    Args:
        input_path: 输入音频文件路径
        output_path: 输出音频文件路径
        target_sr: 目标采样率，默认16000Hz
    """
    try:
        # 加载音频文件
        y, orig_sr = librosa.load(input_path, sr=None)
        
        print(f"处理: {os.path.basename(input_path)}")
        print(f"  原始采样率: {orig_sr}Hz")
        print(f"  音频时长: {len(y)/orig_sr:.2f}秒")
        
        # 重采样
        if orig_sr != target_sr:
            y_resampled = librosa.resample(y, orig_sr=orig_sr, target_sr=target_sr)
            print(f"  重采样到: {target_sr}Hz")
        else:
            y_resampled = y
            print("  采样率已经是16000Hz，无需重采样")
        
        # 保存重采样后的音频
        sf.write(output_path, y_resampled, target_sr)
        print(f"  文件已保存: {output_path}")
        print("  " + "-" * 50)
        
        return True
        
    except Exception as e:
        print(f"错误处理文件 {input_path}: {e}")
        return False

def batch_resample_directory(input_dir, output_dir, target_sr=16000, extensions=None):
    """
    批量重采样目录中的所有音频文件
    
    Args:
        input_dir: 输入目录路径
        output_dir: 输出目录路径
        target_sr: 目标采样率，默认16000Hz
        extensions: 支持的音频文件扩展名列表
    """
    if extensions is None:
        extensions = ['*.wav', '*.mp3', '*.flac', '*.ogg', '*.m4a']
    
    # 创建输出目录
    os.makedirs(output_dir, exist_ok=True)
    
    # 查找所有音频文件
    audio_files = []
    for ext in extensions:
        audio_files.extend(glob.glob(os.path.join(input_dir, ext)))
        audio_files.extend(glob.glob(os.path.join(input_dir, ext.upper())))
    
    print(f"在目录 '{input_dir}' 中找到 {len(audio_files)} 个音频文件")
    print("=" * 60)
    
    success_count = 0
    fail_count = 0
    
    for input_path in audio_files:
        # 生成输出路径（保持原文件名）
        filename = os.path.basename(input_path)
        output_path = os.path.join(output_dir, filename)
        
        # 处理文件
        if resample_wav_librosa(input_path, output_path, target_sr):
            success_count += 1
        else:
            fail_count += 1
    
    print("=" * 60)
    print(f"处理完成！成功: {success_count}, 失败: {fail_count}")

# 使用方法
if __name__ == "__main__":
    #[可配置]
    target_sample_rate = 16000
    # 配置输入输出目录 
    # input_directory = './old_data/compare/data_deal_816_output/'
    # output_directory = './old_data/resample/data_deal_816_output/'
    # batch_resample_directory(input_directory, output_directory, target_sample_rate)

    # input_directory = './new_data/compare/1_output'
    # output_directory = './new_data/resample/1_output/'
    # batch_resample_directory(input_directory, output_directory, target_sample_rate)

    # input_directory = './new_data/compare/2_output'
    # output_directory = './new_data/resample/2_output/'
    # batch_resample_directory(input_directory, output_directory, target_sample_rate)

    # input_directory = './new_data/compare/3_output'
    # output_directory = './new_data/resample/3_output/'
    # batch_resample_directory(input_directory, output_directory, target_sample_rate)

    # input_directory = './new_data/compare/4_output'
    # output_directory = './new_data/resample/4_output/'
    # batch_resample_directory(input_directory, output_directory, target_sample_rate)

    # input_directory = './new_data/compare/5_output'
    # output_directory = './new_data/resample/5_output/'
    # batch_resample_directory(input_directory, output_directory, target_sample_rate)

    # input_directory = './new_data/compare/6_output'
    # output_directory = './new_data/resample/6_output/'
    # batch_resample_directory(input_directory, output_directory, target_sample_rate)

    # print("批量重采样完成！")
# Out:
# 在目录 './old_data/compare/1_output' 中找到 200 个音频文件
# ============================================================
# 处理: synthesized_speech_1.wav
#   原始采样率: 24000Hz
#   音频时长: 0.60秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_1.wav
#   --------------------------------------------------
# 处理: synthesized_speech_2.wav
#   原始采样率: 24000Hz
#   音频时长: 7.72秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_2.wav
#   --------------------------------------------------
# 处理: synthesized_speech_3.wav
#   原始采样率: 24000Hz
#   音频时长: 8.62秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_3.wav
#   --------------------------------------------------
# 处理: synthesized_speech_4.wav
#   原始采样率: 24000Hz
#   音频时长: 3.54秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_4.wav
#   --------------------------------------------------
# 处理: synthesized_speech_5.wav
#   原始采样率: 24000Hz
#   音频时长: 6.70秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_5.wav
#   --------------------------------------------------
# 处理: synthesized_speech_6.wav
#   原始采样率: 24000Hz
#   音频时长: 18.35秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_6.wav
#   --------------------------------------------------
# 处理: synthesized_speech_7.wav
#   原始采样率: 24000Hz
#   音频时长: 14.29秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_7.wav
#   --------------------------------------------------
# 处理: synthesized_speech_8.wav
#   原始采样率: 24000Hz
#   音频时长: 3.54秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_8.wav
#   --------------------------------------------------
# 处理: synthesized_speech_9.wav
#   原始采样率: 24000Hz
#   音频时长: 15.62秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_9.wav
#   --------------------------------------------------
# 处理: synthesized_speech_10.wav
#   原始采样率: 24000Hz
#   音频时长: 4.05秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_10.wav
#   --------------------------------------------------
# 处理: synthesized_speech_11.wav
#   原始采样率: 24000Hz
#   音频时长: 4.78秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_11.wav
#   --------------------------------------------------
# 处理: synthesized_speech_12.wav
#   原始采样率: 24000Hz
#   音频时长: 6.06秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_12.wav
#   --------------------------------------------------
# 处理: synthesized_speech_13.wav
#   原始采样率: 24000Hz
#   音频时长: 5.93秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_13.wav
#   --------------------------------------------------
# 处理: synthesized_speech_14.wav
#   原始采样率: 24000Hz
#   音频时长: 5.80秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_14.wav
#   --------------------------------------------------
# 处理: synthesized_speech_15.wav
#   原始采样率: 24000Hz
#   音频时长: 3.75秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_15.wav
#   --------------------------------------------------
# 处理: synthesized_speech_16.wav
#   原始采样率: 24000Hz
#   音频时长: 2.90秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_16.wav
#   --------------------------------------------------
# 处理: synthesized_speech_17.wav
#   原始采样率: 24000Hz
#   音频时长: 19.54秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_17.wav
#   --------------------------------------------------
# 处理: synthesized_speech_18.wav
#   原始采样率: 24000Hz
#   音频时长: 5.59秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_18.wav
#   --------------------------------------------------
# 处理: synthesized_speech_19.wav
#   原始采样率: 24000Hz
#   音频时长: 9.64秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_19.wav
#   --------------------------------------------------
# 处理: synthesized_speech_20.wav
#   原始采样率: 24000Hz
#   音频时长: 4.18秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_20.wav
#   --------------------------------------------------
# 处理: synthesized_speech_21.wav
#   原始采样率: 24000Hz
#   音频时长: 11.09秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_21.wav
#   --------------------------------------------------
# 处理: synthesized_speech_22.wav
#   原始采样率: 24000Hz
#   音频时长: 5.72秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_22.wav
#   --------------------------------------------------
# 处理: synthesized_speech_23.wav
#   原始采样率: 24000Hz
#   音频时长: 3.93秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_23.wav
#   --------------------------------------------------
# 处理: synthesized_speech_24.wav
#   原始采样率: 24000Hz
#   音频时长: 5.59秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_24.wav
#   --------------------------------------------------
# 处理: synthesized_speech_25.wav
#   原始采样率: 24000Hz
#   音频时长: 4.65秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_25.wav
#   --------------------------------------------------
# 处理: synthesized_speech_26.wav
#   原始采样率: 24000Hz
#   音频时长: 15.74秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_26.wav
#   --------------------------------------------------
# 处理: synthesized_speech_27.wav
#   原始采样率: 24000Hz
#   音频时长: 10.20秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_27.wav
#   --------------------------------------------------
# 处理: synthesized_speech_28.wav
#   原始采样率: 24000Hz
#   音频时长: 9.39秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_28.wav
#   --------------------------------------------------
# 处理: synthesized_speech_29.wav
#   原始采样率: 24000Hz
#   音频时长: 6.95秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_29.wav
#   --------------------------------------------------
# 处理: synthesized_speech_30.wav
#   原始采样率: 24000Hz
#   音频时长: 7.98秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_30.wav
#   --------------------------------------------------
# 处理: synthesized_speech_31.wav
#   原始采样率: 24000Hz
#   音频时长: 4.18秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_31.wav
#   --------------------------------------------------
# 处理: synthesized_speech_32.wav
#   原始采样率: 24000Hz
#   音频时长: 5.21秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_32.wav
#   --------------------------------------------------
# 处理: synthesized_speech_33.wav
#   原始采样率: 24000Hz
#   音频时长: 20.35秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_33.wav
#   --------------------------------------------------
# 处理: synthesized_speech_34.wav
#   原始采样率: 24000Hz
#   音频时长: 1.58秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_34.wav
#   --------------------------------------------------
# 处理: synthesized_speech_35.wav
#   原始采样率: 24000Hz
#   音频时长: 5.08秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_35.wav
#   --------------------------------------------------
# 处理: synthesized_speech_36.wav
#   原始采样率: 24000Hz
#   音频时长: 5.29秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_36.wav
#   --------------------------------------------------
# 处理: synthesized_speech_37.wav
#   原始采样率: 24000Hz
#   音频时长: 4.65秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_37.wav
#   --------------------------------------------------
# 处理: synthesized_speech_38.wav
#   原始采样率: 24000Hz
#   音频时长: 12.25秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_38.wav
#   --------------------------------------------------
# 处理: synthesized_speech_39.wav
#   原始采样率: 24000Hz
#   音频时长: 6.87秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_39.wav
#   --------------------------------------------------
# 处理: synthesized_speech_40.wav
#   原始采样率: 24000Hz
#   音频时长: 11.43秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_40.wav
#   --------------------------------------------------
# 处理: synthesized_speech_41.wav
#   原始采样率: 24000Hz
#   音频时长: 3.50秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_41.wav
#   --------------------------------------------------
# 处理: synthesized_speech_42.wav
#   原始采样率: 24000Hz
#   音频时长: 13.48秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_42.wav
#   --------------------------------------------------
# 处理: synthesized_speech_43.wav
#   原始采样率: 24000Hz
#   音频时长: 8.41秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_43.wav
#   --------------------------------------------------
# 处理: synthesized_speech_44.wav
#   原始采样率: 24000Hz
#   音频时长: 5.59秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_44.wav
#   --------------------------------------------------
# 处理: synthesized_speech_45.wav
#   原始采样率: 24000Hz
#   音频时长: 5.16秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_45.wav
#   --------------------------------------------------
# 处理: synthesized_speech_46.wav
#   原始采样率: 24000Hz
#   音频时长: 3.41秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_46.wav
#   --------------------------------------------------
# 处理: synthesized_speech_47.wav
#   原始采样率: 24000Hz
#   音频时长: 8.49秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_47.wav
#   --------------------------------------------------
# 处理: synthesized_speech_48.wav
#   原始采样率: 24000Hz
#   音频时长: 6.06秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_48.wav
#   --------------------------------------------------
# 处理: synthesized_speech_49.wav
#   原始采样率: 24000Hz
#   音频时长: 5.93秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_49.wav
#   --------------------------------------------------
# 处理: synthesized_speech_50.wav
#   原始采样率: 24000Hz
#   音频时长: 15.96秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_50.wav
#   --------------------------------------------------
# 处理: synthesized_speech_51.wav
#   原始采样率: 24000Hz
#   音频时长: 4.27秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_51.wav
#   --------------------------------------------------
# 处理: synthesized_speech_52.wav
#   原始采样率: 24000Hz
#   音频时长: 14.63秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_52.wav
#   --------------------------------------------------
# 处理: synthesized_speech_53.wav
#   原始采样率: 24000Hz
#   音频时长: 9.56秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_53.wav
#   --------------------------------------------------
# 处理: synthesized_speech_54.wav
#   原始采样率: 24000Hz
#   音频时长: 8.15秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_54.wav
#   --------------------------------------------------
# 处理: synthesized_speech_55.wav
#   原始采样率: 24000Hz
#   音频时长: 4.52秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_55.wav
#   --------------------------------------------------
# 处理: synthesized_speech_56.wav
#   原始采样率: 24000Hz
#   音频时长: 11.31秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_56.wav
#   --------------------------------------------------
# 处理: synthesized_speech_57.wav
#   原始采样率: 24000Hz
#   音频时长: 4.82秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_57.wav
#   --------------------------------------------------
# 处理: synthesized_speech_58.wav
#   原始采样率: 24000Hz
#   音频时长: 5.03秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_58.wav
#   --------------------------------------------------
# 处理: synthesized_speech_59.wav
#   原始采样率: 24000Hz
#   音频时长: 4.65秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_59.wav
#   --------------------------------------------------
# 处理: synthesized_speech_60.wav
#   原始采样率: 24000Hz
#   音频时长: 16.73秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_60.wav
#   --------------------------------------------------
# 处理: synthesized_speech_61.wav
#   原始采样率: 24000Hz
#   音频时长: 7.72秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_61.wav
#   --------------------------------------------------
# 处理: synthesized_speech_62.wav
#   原始采样率: 24000Hz
#   音频时长: 5.55秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_62.wav
#   --------------------------------------------------
# 处理: synthesized_speech_63.wav
#   原始采样率: 24000Hz
#   音频时长: 6.19秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_63.wav
#   --------------------------------------------------
# 处理: synthesized_speech_64.wav
#   原始采样率: 24000Hz
#   音频时长: 6.31秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_64.wav
#   --------------------------------------------------
# 处理: synthesized_speech_65.wav
#   原始采样率: 24000Hz
#   音频时长: 3.11秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_65.wav
#   --------------------------------------------------
# 处理: synthesized_speech_66.wav
#   原始采样率: 24000Hz
#   音频时长: 3.54秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_66.wav
#   --------------------------------------------------
# 处理: synthesized_speech_67.wav
#   原始采样率: 24000Hz
#   音频时长: 118.95秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_67.wav
#   --------------------------------------------------
# 处理: synthesized_speech_68.wav
#   原始采样率: 24000Hz
#   音频时长: 9.81秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_68.wav
#   --------------------------------------------------
# 处理: synthesized_speech_69.wav
#   原始采样率: 24000Hz
#   音频时长: 5.08秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_69.wav
#   --------------------------------------------------
# 处理: synthesized_speech_70.wav
#   原始采样率: 24000Hz
#   音频时长: 6.23秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_70.wav
#   --------------------------------------------------
# 处理: synthesized_speech_71.wav
#   原始采样率: 24000Hz
#   音频时长: 5.59秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_71.wav
#   --------------------------------------------------
# 处理: synthesized_speech_72.wav
#   原始采样率: 24000Hz
#   音频时长: 6.10秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_72.wav
#   --------------------------------------------------
# 处理: synthesized_speech_73.wav
#   原始采样率: 24000Hz
#   音频时长: 3.75秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_73.wav
#   --------------------------------------------------
# 处理: synthesized_speech_74.wav
#   原始采样率: 24000Hz
#   音频时长: 3.75秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_74.wav
#   --------------------------------------------------
# 处理: synthesized_speech_75.wav
#   原始采样率: 24000Hz
#   音频时长: 5.93秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_75.wav
#   --------------------------------------------------
# 处理: synthesized_speech_76.wav
#   原始采样率: 24000Hz
#   音频时长: 9.81秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_76.wav
#   --------------------------------------------------
# 处理: synthesized_speech_77.wav
#   原始采样率: 24000Hz
#   音频时长: 32.98秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_77.wav
#   --------------------------------------------------
# 处理: synthesized_speech_78.wav
#   原始采样率: 24000Hz
#   音频时长: 24.70秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_78.wav
#   --------------------------------------------------
# 处理: synthesized_speech_79.wav
#   原始采样率: 24000Hz
#   音频时长: 4.91秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_79.wav
#   --------------------------------------------------
# 处理: synthesized_speech_80.wav
#   原始采样率: 24000Hz
#   音频时长: 45.61秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_80.wav
#   --------------------------------------------------
# 处理: synthesized_speech_81.wav
#   原始采样率: 24000Hz
#   音频时长: 8.15秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_81.wav
#   --------------------------------------------------
# 处理: synthesized_speech_82.wav
#   原始采样率: 24000Hz
#   音频时长: 9.51秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_82.wav
#   --------------------------------------------------
# 处理: synthesized_speech_83.wav
#   原始采样率: 24000Hz
#   音频时长: 2.39秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_83.wav
#   --------------------------------------------------
# 处理: synthesized_speech_84.wav
#   原始采样率: 24000Hz
#   音频时长: 28.33秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_84.wav
#   --------------------------------------------------
# 处理: synthesized_speech_85.wav
#   原始采样率: 24000Hz
#   音频时长: 4.69秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_85.wav
#   --------------------------------------------------
# 处理: synthesized_speech_86.wav
#   原始采样率: 24000Hz
#   音频时长: 3.29秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_86.wav
#   --------------------------------------------------
# 处理: synthesized_speech_87.wav
#   原始采样率: 24000Hz
#   音频时长: 5.55秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_87.wav
#   --------------------------------------------------
# 处理: synthesized_speech_88.wav
#   原始采样率: 24000Hz
#   音频时长: 6.44秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_88.wav
#   --------------------------------------------------
# 处理: synthesized_speech_89.wav
#   原始采样率: 24000Hz
#   音频时长: 6.61秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_89.wav
#   --------------------------------------------------
# 处理: synthesized_speech_90.wav
#   原始采样率: 24000Hz
#   音频时长: 8.15秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_90.wav
#   --------------------------------------------------
# 处理: synthesized_speech_91.wav
#   原始采样率: 24000Hz
#   音频时长: 2.47秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_91.wav
#   --------------------------------------------------
# 处理: synthesized_speech_92.wav
#   原始采样率: 24000Hz
#   音频时长: 3.80秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_92.wav
#   --------------------------------------------------
# 处理: synthesized_speech_93.wav
#   原始采样率: 24000Hz
#   音频时长: 11.22秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_93.wav
#   --------------------------------------------------
# 处理: synthesized_speech_94.wav
#   原始采样率: 24000Hz
#   音频时长: 82.09秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_94.wav
#   --------------------------------------------------
# 处理: synthesized_speech_95.wav
#   原始采样率: 24000Hz
#   音频时长: 6.57秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_95.wav
#   --------------------------------------------------
# 处理: synthesized_speech_96.wav
#   原始采样率: 24000Hz
#   音频时长: 11.82秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_96.wav
#   --------------------------------------------------
# 处理: synthesized_speech_97.wav
#   原始采样率: 24000Hz
#   音频时长: 18.94秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_97.wav
#   --------------------------------------------------
# 处理: synthesized_speech_98.wav
#   原始采样率: 24000Hz
#   音频时长: 4.14秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_98.wav
#   --------------------------------------------------
# 处理: synthesized_speech_99.wav
#   原始采样率: 24000Hz
#   音频时长: 8.11秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_99.wav
#   --------------------------------------------------
# 处理: synthesized_speech_100.wav
#   原始采样率: 24000Hz
#   音频时长: 4.39秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_100.wav
#   --------------------------------------------------
# 处理: synthesized_speech_101.wav
#   原始采样率: 24000Hz
#   音频时长: 10.79秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_101.wav
#   --------------------------------------------------
# 处理: synthesized_speech_102.wav
#   原始采样率: 24000Hz
#   音频时长: 4.05秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_102.wav
#   --------------------------------------------------
# 处理: synthesized_speech_103.wav
#   原始采样率: 24000Hz
#   音频时长: 3.63秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_103.wav
#   --------------------------------------------------
# 处理: synthesized_speech_104.wav
#   原始采样率: 24000Hz
#   音频时长: 14.55秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_104.wav
#   --------------------------------------------------
# 处理: synthesized_speech_105.wav
#   原始采样率: 24000Hz
#   音频时长: 8.75秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_105.wav
#   --------------------------------------------------
# 处理: synthesized_speech_106.wav
#   原始采样率: 24000Hz
#   音频时长: 26.84秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_106.wav
#   --------------------------------------------------
# 处理: synthesized_speech_107.wav
#   原始采样率: 24000Hz
#   音频时长: 4.39秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_107.wav
#   --------------------------------------------------
# 处理: synthesized_speech_108.wav
#   原始采样率: 24000Hz
#   音频时长: 7.25秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_108.wav
#   --------------------------------------------------
# 处理: synthesized_speech_109.wav
#   原始采样率: 24000Hz
#   音频时长: 4.27秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_109.wav
#   --------------------------------------------------
# 处理: synthesized_speech_110.wav
#   原始采样率: 24000Hz
#   音频时长: 3.75秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_110.wav
#   --------------------------------------------------
# 处理: synthesized_speech_111.wav
#   原始采样率: 24000Hz
#   音频时长: 5.67秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_111.wav
#   --------------------------------------------------
# 处理: synthesized_speech_112.wav
#   原始采样率: 24000Hz
#   音频时长: 4.27秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_112.wav
#   --------------------------------------------------
# 处理: synthesized_speech_113.wav
#   原始采样率: 24000Hz
#   音频时长: 9.26秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_113.wav
#   --------------------------------------------------
# 处理: synthesized_speech_114.wav
#   原始采样率: 24000Hz
#   音频时长: 6.44秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_114.wav
#   --------------------------------------------------
# 处理: synthesized_speech_115.wav
#   原始采样率: 24000Hz
#   音频时长: 8.23秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_115.wav
#   --------------------------------------------------
# 处理: synthesized_speech_116.wav
#   原始采样率: 24000Hz
#   音频时长: 7.21秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_116.wav
#   --------------------------------------------------
# 处理: synthesized_speech_117.wav
#   原始采样率: 24000Hz
#   音频时长: 21.89秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_117.wav
#   --------------------------------------------------
# 处理: synthesized_speech_118.wav
#   原始采样率: 24000Hz
#   音频时长: 7.08秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_118.wav
#   --------------------------------------------------
# 处理: synthesized_speech_119.wav
#   原始采样率: 24000Hz
#   音频时长: 18.13秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_119.wav
#   --------------------------------------------------
# 处理: synthesized_speech_120.wav
#   原始采样率: 24000Hz
#   音频时长: 4.65秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_120.wav
#   --------------------------------------------------
# 处理: synthesized_speech_121.wav
#   原始采样率: 24000Hz
#   音频时长: 7.38秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_121.wav
#   --------------------------------------------------
# 处理: synthesized_speech_122.wav
#   原始采样率: 24000Hz
#   音频时长: 1.88秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_122.wav
#   --------------------------------------------------
# 处理: synthesized_speech_123.wav
#   原始采样率: 24000Hz
#   音频时长: 4.65秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_123.wav
#   --------------------------------------------------
# 处理: synthesized_speech_124.wav
#   原始采样率: 24000Hz
#   音频时长: 5.42秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_124.wav
#   --------------------------------------------------
# 处理: synthesized_speech_125.wav
#   原始采样率: 24000Hz
#   音频时长: 1.71秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_125.wav
#   --------------------------------------------------
# 处理: synthesized_speech_126.wav
#   原始采样率: 24000Hz
#   音频时长: 3.63秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_126.wav
#   --------------------------------------------------
# 处理: synthesized_speech_127.wav
#   原始采样率: 24000Hz
#   音频时长: 9.26秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_127.wav
#   --------------------------------------------------
# 处理: synthesized_speech_128.wav
#   原始采样率: 24000Hz
#   音频时长: 5.85秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_128.wav
#   --------------------------------------------------
# 处理: synthesized_speech_129.wav
#   原始采样率: 24000Hz
#   音频时长: 12.89秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_129.wav
#   --------------------------------------------------
# 处理: synthesized_speech_130.wav
#   原始采样率: 24000Hz
#   音频时长: 5.80秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_130.wav
#   --------------------------------------------------
# 处理: synthesized_speech_131.wav
#   原始采样率: 24000Hz
#   音频时长: 4.27秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_131.wav
#   --------------------------------------------------
# 处理: synthesized_speech_132.wav
#   原始采样率: 24000Hz
#   音频时长: 19.20秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_132.wav
#   --------------------------------------------------
# 处理: synthesized_speech_133.wav
#   原始采样率: 24000Hz
#   音频时长: 3.24秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_133.wav
#   --------------------------------------------------
# 处理: synthesized_speech_134.wav
#   原始采样率: 24000Hz
#   音频时长: 12.84秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_134.wav
#   --------------------------------------------------
# 处理: synthesized_speech_135.wav
#   原始采样率: 24000Hz
#   音频时长: 3.41秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_135.wav
#   --------------------------------------------------
# 处理: synthesized_speech_136.wav
#   原始采样率: 24000Hz
#   音频时长: 6.36秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_136.wav
#   --------------------------------------------------
# 处理: synthesized_speech_137.wav
#   原始采样率: 24000Hz
#   音频时长: 19.71秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_137.wav
#   --------------------------------------------------
# 处理: synthesized_speech_138.wav
#   原始采样率: 24000Hz
#   音频时长: 7.34秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_138.wav
#   --------------------------------------------------
# 处理: synthesized_speech_139.wav
#   原始采样率: 24000Hz
#   音频时长: 9.26秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_139.wav
#   --------------------------------------------------
# 处理: synthesized_speech_140.wav
#   原始采样率: 24000Hz
#   音频时长: 8.28秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_140.wav
#   --------------------------------------------------
# 处理: synthesized_speech_141.wav
#   原始采样率: 24000Hz
#   音频时长: 9.64秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_141.wav
#   --------------------------------------------------
# 处理: synthesized_speech_142.wav
#   原始采样率: 24000Hz
#   音频时长: 8.66秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_142.wav
#   --------------------------------------------------
# 处理: synthesized_speech_143.wav
#   原始采样率: 24000Hz
#   音频时长: 2.60秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_143.wav
#   --------------------------------------------------
# 处理: synthesized_speech_144.wav
#   原始采样率: 24000Hz
#   音频时长: 5.59秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_144.wav
#   --------------------------------------------------
# 处理: synthesized_speech_145.wav
#   原始采样率: 24000Hz
#   音频时长: 2.99秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_145.wav
#   --------------------------------------------------
# 处理: synthesized_speech_146.wav
#   原始采样率: 24000Hz
#   音频时长: 4.91秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_146.wav
#   --------------------------------------------------
# 处理: synthesized_speech_147.wav
#   原始采样率: 24000Hz
#   音频时长: 28.97秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_147.wav
#   --------------------------------------------------
# 处理: synthesized_speech_148.wav
#   原始采样率: 24000Hz
#   音频时长: 4.39秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_148.wav
#   --------------------------------------------------
# 处理: synthesized_speech_149.wav
#   原始采样率: 24000Hz
#   音频时长: 16.47秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_149.wav
#   --------------------------------------------------
# 处理: synthesized_speech_150.wav
#   原始采样率: 24000Hz
#   音频时长: 7.21秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_150.wav
#   --------------------------------------------------
# 处理: synthesized_speech_151.wav
#   原始采样率: 24000Hz
#   音频时长: 5.29秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_151.wav
#   --------------------------------------------------
# 处理: synthesized_speech_152.wav
#   原始采样率: 24000Hz
#   音频时长: 2.26秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_152.wav
#   --------------------------------------------------
# 处理: synthesized_speech_153.wav
#   原始采样率: 24000Hz
#   音频时长: 5.16秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_153.wav
#   --------------------------------------------------
# 处理: synthesized_speech_154.wav
#   原始采样率: 24000Hz
#   音频时长: 4.57秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_154.wav
#   --------------------------------------------------
# 处理: synthesized_speech_155.wav
#   原始采样率: 24000Hz
#   音频时长: 13.35秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_155.wav
#   --------------------------------------------------
# 处理: synthesized_speech_156.wav
#   原始采样率: 24000Hz
#   音频时长: 10.28秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_156.wav
#   --------------------------------------------------
# 处理: synthesized_speech_157.wav
#   原始采样率: 24000Hz
#   音频时长: 5.08秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_157.wav
#   --------------------------------------------------
# 处理: synthesized_speech_158.wav
#   原始采样率: 24000Hz
#   音频时长: 9.56秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_158.wav
#   --------------------------------------------------
# 处理: synthesized_speech_159.wav
#   原始采样率: 24000Hz
#   音频时长: 3.11秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_159.wav
#   --------------------------------------------------
# 处理: synthesized_speech_160.wav
#   原始采样率: 24000Hz
#   音频时长: 6.36秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_160.wav
#   --------------------------------------------------
# 处理: synthesized_speech_161.wav
#   原始采样率: 24000Hz
#   音频时长: 16.55秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_161.wav
#   --------------------------------------------------
# 处理: synthesized_speech_162.wav
#   原始采样率: 24000Hz
#   音频时长: 21.85秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_162.wav
#   --------------------------------------------------
# 处理: synthesized_speech_163.wav
#   原始采样率: 24000Hz
#   音频时长: 4.05秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_163.wav
#   --------------------------------------------------
# 处理: synthesized_speech_164.wav
#   原始采样率: 24000Hz
#   音频时长: 7.77秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_164.wav
#   --------------------------------------------------
# 处理: synthesized_speech_165.wav
#   原始采样率: 24000Hz
#   音频时长: 5.93秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_165.wav
#   --------------------------------------------------
# 处理: synthesized_speech_166.wav
#   原始采样率: 24000Hz
#   音频时长: 19.03秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_166.wav
#   --------------------------------------------------
# 处理: synthesized_speech_167.wav
#   原始采样率: 24000Hz
#   音频时长: 8.79秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_167.wav
#   --------------------------------------------------
# 处理: synthesized_speech_168.wav
#   原始采样率: 24000Hz
#   音频时长: 4.52秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_168.wav
#   --------------------------------------------------
# 处理: synthesized_speech_169.wav
#   原始采样率: 24000Hz
#   音频时长: 9.51秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_169.wav
#   --------------------------------------------------
# 处理: synthesized_speech_170.wav
#   原始采样率: 24000Hz
#   音频时长: 4.14秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_170.wav
#   --------------------------------------------------
# 处理: synthesized_speech_171.wav
#   原始采样率: 24000Hz
#   音频时长: 4.39秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_171.wav
#   --------------------------------------------------
# 处理: synthesized_speech_172.wav
#   原始采样率: 24000Hz
#   音频时长: 8.02秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_172.wav
#   --------------------------------------------------
# 处理: synthesized_speech_173.wav
#   原始采样率: 24000Hz
#   音频时长: 16.90秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_173.wav
#   --------------------------------------------------
# 处理: synthesized_speech_174.wav
#   原始采样率: 24000Hz
#   音频时长: 6.70秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_174.wav
#   --------------------------------------------------
# 处理: synthesized_speech_175.wav
#   原始采样率: 24000Hz
#   音频时长: 2.90秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_175.wav
#   --------------------------------------------------
# 处理: synthesized_speech_176.wav
#   原始采样率: 24000Hz
#   音频时长: 6.83秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_176.wav
#   --------------------------------------------------
# 处理: synthesized_speech_177.wav
#   原始采样率: 24000Hz
#   音频时长: 4.44秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_177.wav
#   --------------------------------------------------
# 处理: synthesized_speech_178.wav
#   原始采样率: 24000Hz
#   音频时长: 8.23秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_178.wav
#   --------------------------------------------------
# 处理: synthesized_speech_179.wav
#   原始采样率: 24000Hz
#   音频时长: 6.83秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_179.wav
#   --------------------------------------------------
# 处理: synthesized_speech_180.wav
#   原始采样率: 24000Hz
#   音频时长: 6.06秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_180.wav
#   --------------------------------------------------
# 处理: synthesized_speech_181.wav
#   原始采样率: 24000Hz
#   音频时长: 4.52秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_181.wav
#   --------------------------------------------------
# 处理: synthesized_speech_182.wav
#   原始采样率: 24000Hz
#   音频时长: 4.82秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_182.wav
#   --------------------------------------------------
# 处理: synthesized_speech_183.wav
#   原始采样率: 24000Hz
#   音频时长: 6.95秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_183.wav
#   --------------------------------------------------
# 处理: synthesized_speech_184.wav
#   原始采样率: 24000Hz
#   音频时长: 5.33秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_184.wav
#   --------------------------------------------------
# 处理: synthesized_speech_185.wav
#   原始采样率: 24000Hz
#   音频时长: 8.11秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_185.wav
#   --------------------------------------------------
# 处理: synthesized_speech_186.wav
#   原始采样率: 24000Hz
#   音频时长: 5.33秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_186.wav
#   --------------------------------------------------
# 处理: synthesized_speech_187.wav
#   原始采样率: 24000Hz
#   音频时长: 9.69秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_187.wav
#   --------------------------------------------------
# 处理: synthesized_speech_188.wav
#   原始采样率: 24000Hz
#   音频时长: 9.56秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_188.wav
#   --------------------------------------------------
# 处理: synthesized_speech_189.wav
#   原始采样率: 24000Hz
#   音频时长: 11.18秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_189.wav
#   --------------------------------------------------
# 处理: synthesized_speech_190.wav
#   原始采样率: 24000Hz
#   音频时长: 64.90秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_190.wav
#   --------------------------------------------------
# 处理: synthesized_speech_191.wav
#   原始采样率: 24000Hz
#   音频时长: 4.31秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_191.wav
#   --------------------------------------------------
# 处理: synthesized_speech_192.wav
#   原始采样率: 24000Hz
#   音频时长: 7.98秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_192.wav
#   --------------------------------------------------
# 处理: synthesized_speech_193.wav
#   原始采样率: 24000Hz
#   音频时长: 3.24秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_193.wav
#   --------------------------------------------------
# 处理: synthesized_speech_194.wav
#   原始采样率: 24000Hz
#   音频时长: 0.68秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_194.wav
#   --------------------------------------------------
# 处理: synthesized_speech_195.wav
#   原始采样率: 24000Hz
#   音频时长: 4.52秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_195.wav
#   --------------------------------------------------
# 处理: synthesized_speech_196.wav
#   原始采样率: 24000Hz
#   音频时长: 21.25秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_196.wav
#   --------------------------------------------------
# 处理: synthesized_speech_197.wav
#   原始采样率: 24000Hz
#   音频时长: 3.16秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_197.wav
#   --------------------------------------------------
# 处理: synthesized_speech_198.wav
#   原始采样率: 24000Hz
#   音频时长: 9.94秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_198.wav
#   --------------------------------------------------
# 处理: synthesized_speech_199.wav
#   原始采样率: 24000Hz
#   音频时长: 64.73秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_199.wav
#   --------------------------------------------------
# 处理: synthesized_speech_200.wav
#   原始采样率: 24000Hz
#   音频时长: 6.23秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/1_output/synthesized_speech_200.wav
#   --------------------------------------------------
# ============================================================
# 处理完成！成功: 200, 失败: 0
# 在目录 './old_data/compare/2_output' 中找到 200 个音频文件
# ============================================================
# 处理: synthesized_speech_1.wav
#   原始采样率: 24000Hz
#   音频时长: 0.60秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_1.wav
#   --------------------------------------------------
# 处理: synthesized_speech_2.wav
#   原始采样率: 24000Hz
#   音频时长: 6.31秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_2.wav
#   --------------------------------------------------
# 处理: synthesized_speech_3.wav
#   原始采样率: 24000Hz
#   音频时长: 7.98秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_3.wav
#   --------------------------------------------------
# 处理: synthesized_speech_4.wav
#   原始采样率: 24000Hz
#   音频时长: 3.54秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_4.wav
#   --------------------------------------------------
# 处理: synthesized_speech_5.wav
#   原始采样率: 24000Hz
#   音频时长: 7.08秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_5.wav
#   --------------------------------------------------
# 处理: synthesized_speech_6.wav
#   原始采样率: 24000Hz
#   音频时长: 18.69秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_6.wav
#   --------------------------------------------------
# 处理: synthesized_speech_7.wav
#   原始采样率: 24000Hz
#   音频时长: 14.55秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_7.wav
#   --------------------------------------------------
# 处理: synthesized_speech_8.wav
#   原始采样率: 24000Hz
#   音频时长: 3.54秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_8.wav
#   --------------------------------------------------
# 处理: synthesized_speech_9.wav
#   原始采样率: 24000Hz
#   音频时长: 15.66秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_9.wav
#   --------------------------------------------------
# 处理: synthesized_speech_10.wav
#   原始采样率: 24000Hz
#   音频时长: 4.31秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_10.wav
#   --------------------------------------------------
# 处理: synthesized_speech_11.wav
#   原始采样率: 24000Hz
#   音频时长: 4.78秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_11.wav
#   --------------------------------------------------
# 处理: synthesized_speech_12.wav
#   原始采样率: 24000Hz
#   音频时长: 6.31秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_12.wav
#   --------------------------------------------------
# 处理: synthesized_speech_13.wav
#   原始采样率: 24000Hz
#   音频时长: 6.10秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_13.wav
#   --------------------------------------------------
# 处理: synthesized_speech_14.wav
#   原始采样率: 24000Hz
#   音频时长: 5.55秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_14.wav
#   --------------------------------------------------
# 处理: synthesized_speech_15.wav
#   原始采样率: 24000Hz
#   音频时长: 3.88秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_15.wav
#   --------------------------------------------------
# 处理: synthesized_speech_16.wav
#   原始采样率: 24000Hz
#   音频时长: 2.77秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_16.wav
#   --------------------------------------------------
# 处理: synthesized_speech_17.wav
#   原始采样率: 24000Hz
#   音频时长: 19.46秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_17.wav
#   --------------------------------------------------
# 处理: synthesized_speech_18.wav
#   原始采样率: 24000Hz
#   音频时长: 6.06秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_18.wav
#   --------------------------------------------------
# 处理: synthesized_speech_19.wav
#   原始采样率: 24000Hz
#   音频时长: 8.66秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_19.wav
#   --------------------------------------------------
# 处理: synthesized_speech_20.wav
#   原始采样率: 24000Hz
#   音频时长: 4.39秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_20.wav
#   --------------------------------------------------
# 处理: synthesized_speech_21.wav
#   原始采样率: 24000Hz
#   音频时长: 12.71秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_21.wav
#   --------------------------------------------------
# 处理: synthesized_speech_22.wav
#   原始采样率: 24000Hz
#   音频时长: 3.67秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_22.wav
#   --------------------------------------------------
# 处理: synthesized_speech_23.wav
#   原始采样率: 24000Hz
#   音频时长: 3.67秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_23.wav
#   --------------------------------------------------
# 处理: synthesized_speech_24.wav
#   原始采样率: 24000Hz
#   音频时长: 5.72秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_24.wav
#   --------------------------------------------------
# 处理: synthesized_speech_25.wav
#   原始采样率: 24000Hz
#   音频时长: 5.03秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_25.wav
#   --------------------------------------------------
# 处理: synthesized_speech_26.wav
#   原始采样率: 24000Hz
#   音频时长: 16.85秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_26.wav
#   --------------------------------------------------
# 处理: synthesized_speech_27.wav
#   原始采样率: 24000Hz
#   音频时长: 10.41秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_27.wav
#   --------------------------------------------------
# 处理: synthesized_speech_28.wav
#   原始采样率: 24000Hz
#   音频时长: 11.05秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_28.wav
#   --------------------------------------------------
# 处理: synthesized_speech_29.wav
#   原始采样率: 24000Hz
#   音频时长: 6.70秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_29.wav
#   --------------------------------------------------
# 处理: synthesized_speech_30.wav
#   原始采样率: 24000Hz
#   音频时长: 6.95秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_30.wav
#   --------------------------------------------------
# 处理: synthesized_speech_31.wav
#   原始采样率: 24000Hz
#   音频时长: 3.88秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_31.wav
#   --------------------------------------------------
# 处理: synthesized_speech_32.wav
#   原始采样率: 24000Hz
#   音频时长: 4.69秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_32.wav
#   --------------------------------------------------
# 处理: synthesized_speech_33.wav
#   原始采样率: 24000Hz
#   音频时长: 21.46秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_33.wav
#   --------------------------------------------------
# 处理: synthesized_speech_34.wav
#   原始采样率: 24000Hz
#   音频时长: 1.45秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_34.wav
#   --------------------------------------------------
# 处理: synthesized_speech_35.wav
#   原始采样率: 24000Hz
#   音频时长: 5.93秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_35.wav
#   --------------------------------------------------
# 处理: synthesized_speech_36.wav
#   原始采样率: 24000Hz
#   音频时长: 5.29秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_36.wav
#   --------------------------------------------------
# 处理: synthesized_speech_37.wav
#   原始采样率: 24000Hz
#   音频时长: 4.57秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_37.wav
#   --------------------------------------------------
# 处理: synthesized_speech_38.wav
#   原始采样率: 24000Hz
#   音频时长: 12.33秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_38.wav
#   --------------------------------------------------
# 处理: synthesized_speech_39.wav
#   原始采样率: 24000Hz
#   音频时长: 6.57秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_39.wav
#   --------------------------------------------------
# 处理: synthesized_speech_40.wav
#   原始采样率: 24000Hz
#   音频时长: 11.48秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_40.wav
#   --------------------------------------------------
# 处理: synthesized_speech_41.wav
#   原始采样率: 24000Hz
#   音频时长: 3.24秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_41.wav
#   --------------------------------------------------
# 处理: synthesized_speech_42.wav
#   原始采样率: 24000Hz
#   音频时长: 14.08秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_42.wav
#   --------------------------------------------------
# 处理: synthesized_speech_43.wav
#   原始采样率: 24000Hz
#   音频时长: 8.02秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_43.wav
#   --------------------------------------------------
# 处理: synthesized_speech_44.wav
#   原始采样率: 24000Hz
#   音频时长: 5.55秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_44.wav
#   --------------------------------------------------
# 处理: synthesized_speech_45.wav
#   原始采样率: 24000Hz
#   音频时长: 5.46秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/2_output/synthesized_speech_45.wav
# ...
# 处理: synthesized_speech_100.wav
#   原始采样率: 24000Hz
#   音频时长: 4.44秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_100.wav
#   --------------------------------------------------
# 处理: synthesized_speech_101.wav
#   原始采样率: 24000Hz
#   音频时长: 10.45秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_101.wav
#   --------------------------------------------------
# 处理: synthesized_speech_102.wav
#   原始采样率: 24000Hz
#   音频时长: 4.31秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_102.wav
#   --------------------------------------------------
# 处理: synthesized_speech_103.wav
#   原始采样率: 24000Hz
#   音频时长: 3.75秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_103.wav
#   --------------------------------------------------
# 处理: synthesized_speech_104.wav
#   原始采样率: 24000Hz
#   音频时长: 13.23秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_104.wav
#   --------------------------------------------------
# 处理: synthesized_speech_105.wav
#   原始采样率: 24000Hz
#   音频时长: 8.92秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_105.wav
#   --------------------------------------------------
# 处理: synthesized_speech_106.wav
#   原始采样率: 24000Hz
#   音频时长: 26.75秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_106.wav
#   --------------------------------------------------
# 处理: synthesized_speech_107.wav
#   原始采样率: 24000Hz
#   音频时长: 5.72秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_107.wav
#   --------------------------------------------------
# 处理: synthesized_speech_108.wav
#   原始采样率: 24000Hz
#   音频时长: 7.47秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_108.wav
#   --------------------------------------------------
# 处理: synthesized_speech_109.wav
#   原始采样率: 24000Hz
#   音频时长: 5.08秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_109.wav
#   --------------------------------------------------
# 处理: synthesized_speech_110.wav
#   原始采样率: 24000Hz
#   音频时长: 3.67秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_110.wav
#   --------------------------------------------------
# 处理: synthesized_speech_111.wav
#   原始采样率: 24000Hz
#   音频时长: 5.85秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_111.wav
#   --------------------------------------------------
# 处理: synthesized_speech_112.wav
#   原始采样率: 24000Hz
#   音频时长: 4.39秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_112.wav
#   --------------------------------------------------
# 处理: synthesized_speech_113.wav
#   原始采样率: 24000Hz
#   音频时长: 9.77秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_113.wav
#   --------------------------------------------------
# 处理: synthesized_speech_114.wav
#   原始采样率: 24000Hz
#   音频时长: 5.80秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_114.wav
#   --------------------------------------------------
# 处理: synthesized_speech_115.wav
#   原始采样率: 24000Hz
#   音频时长: 8.62秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_115.wav
#   --------------------------------------------------
# 处理: synthesized_speech_116.wav
#   原始采样率: 24000Hz
#   音频时长: 7.77秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_116.wav
#   --------------------------------------------------
# 处理: synthesized_speech_117.wav
#   原始采样率: 24000Hz
#   音频时长: 22.36秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_117.wav
#   --------------------------------------------------
# 处理: synthesized_speech_118.wav
#   原始采样率: 24000Hz
#   音频时长: 7.21秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_118.wav
#   --------------------------------------------------
# 处理: synthesized_speech_119.wav
#   原始采样率: 24000Hz
#   音频时长: 18.73秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_119.wav
#   --------------------------------------------------
# 处理: synthesized_speech_120.wav
#   原始采样率: 24000Hz
#   音频时长: 4.65秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_120.wav
#   --------------------------------------------------
# 处理: synthesized_speech_121.wav
#   原始采样率: 24000Hz
#   音频时长: 7.47秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_121.wav
#   --------------------------------------------------
# 处理: synthesized_speech_122.wav
#   原始采样率: 24000Hz
#   音频时长: 1.75秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_122.wav
#   --------------------------------------------------
# 处理: synthesized_speech_123.wav
#   原始采样率: 24000Hz
#   音频时长: 4.31秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_123.wav
#   --------------------------------------------------
# 处理: synthesized_speech_124.wav
#   原始采样率: 24000Hz
#   音频时长: 5.29秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_124.wav
#   --------------------------------------------------
# 处理: synthesized_speech_125.wav
#   原始采样率: 24000Hz
#   音频时长: 1.71秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_125.wav
#   --------------------------------------------------
# 处理: synthesized_speech_126.wav
#   原始采样率: 24000Hz
#   音频时长: 3.37秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_126.wav
#   --------------------------------------------------
# 处理: synthesized_speech_127.wav
#   原始采样率: 24000Hz
#   音频时长: 8.87秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_127.wav
#   --------------------------------------------------
# 处理: synthesized_speech_128.wav
#   原始采样率: 24000Hz
#   音频时长: 5.67秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_128.wav
#   --------------------------------------------------
# 处理: synthesized_speech_129.wav
#   原始采样率: 24000Hz
#   音频时长: 12.84秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_129.wav
#   --------------------------------------------------
# 处理: synthesized_speech_130.wav
#   原始采样率: 24000Hz
#   音频时长: 5.85秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_130.wav
#   --------------------------------------------------
# 处理: synthesized_speech_131.wav
#   原始采样率: 24000Hz
#   音频时长: 4.14秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_131.wav
#   --------------------------------------------------
# 处理: synthesized_speech_132.wav
#   原始采样率: 24000Hz
#   音频时长: 18.99秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_132.wav
#   --------------------------------------------------
# 处理: synthesized_speech_133.wav
#   原始采样率: 24000Hz
#   音频时长: 3.41秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_133.wav
#   --------------------------------------------------
# 处理: synthesized_speech_134.wav
#   原始采样率: 24000Hz
#   音频时长: 12.59秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_134.wav
#   --------------------------------------------------
# 处理: synthesized_speech_135.wav
#   原始采样率: 24000Hz
#   音频时长: 3.63秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_135.wav
#   --------------------------------------------------
# 处理: synthesized_speech_136.wav
#   原始采样率: 24000Hz
#   音频时长: 6.31秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_136.wav
#   --------------------------------------------------
# 处理: synthesized_speech_137.wav
#   原始采样率: 24000Hz
#   音频时长: 19.84秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_137.wav
#   --------------------------------------------------
# 处理: synthesized_speech_138.wav
#   原始采样率: 24000Hz
#   音频时长: 7.38秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_138.wav
#   --------------------------------------------------
# 处理: synthesized_speech_139.wav
#   原始采样率: 24000Hz
#   音频时长: 8.49秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_139.wav
#   --------------------------------------------------
# 处理: synthesized_speech_140.wav
#   原始采样率: 24000Hz
#   音频时长: 8.75秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_140.wav
#   --------------------------------------------------
# 处理: synthesized_speech_141.wav
#   原始采样率: 24000Hz
#   音频时长: 9.90秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_141.wav
#   --------------------------------------------------
# 处理: synthesized_speech_142.wav
#   原始采样率: 24000Hz
#   音频时长: 8.23秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_142.wav
#   --------------------------------------------------
# 处理: synthesized_speech_143.wav
#   原始采样率: 24000Hz
#   音频时长: 2.52秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_143.wav
#   --------------------------------------------------
# 处理: synthesized_speech_144.wav
#   原始采样率: 24000Hz
#   音频时长: 5.21秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_144.wav
#   --------------------------------------------------
# 处理: synthesized_speech_145.wav
#   原始采样率: 24000Hz
#   音频时长: 2.99秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_145.wav
#   --------------------------------------------------
# 处理: synthesized_speech_146.wav
#   原始采样率: 24000Hz
#   音频时长: 5.16秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_146.wav
#   --------------------------------------------------
# 处理: synthesized_speech_147.wav
#   原始采样率: 24000Hz
#   音频时长: 28.89秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_147.wav
#   --------------------------------------------------
# 处理: synthesized_speech_148.wav
#   原始采样率: 24000Hz
#   音频时长: 4.27秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_148.wav
#   --------------------------------------------------
# 处理: synthesized_speech_149.wav
#   原始采样率: 24000Hz
#   音频时长: 17.32秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_149.wav
#   --------------------------------------------------
# 处理: synthesized_speech_150.wav
#   原始采样率: 24000Hz
#   音频时长: 6.44秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_150.wav
#   --------------------------------------------------
# 处理: synthesized_speech_151.wav
#   原始采样率: 24000Hz
#   音频时长: 5.08秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_151.wav
#   --------------------------------------------------
# 处理: synthesized_speech_152.wav
#   原始采样率: 24000Hz
#   音频时长: 2.01秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_152.wav
#   --------------------------------------------------
# 处理: synthesized_speech_153.wav
#   原始采样率: 24000Hz
#   音频时长: 5.55秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_153.wav
#   --------------------------------------------------
# 处理: synthesized_speech_154.wav
#   原始采样率: 24000Hz
#   音频时长: 5.03秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_154.wav
#   --------------------------------------------------
# 处理: synthesized_speech_155.wav
#   原始采样率: 24000Hz
#   音频时长: 13.35秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_155.wav
#   --------------------------------------------------
# 处理: synthesized_speech_156.wav
#   原始采样率: 24000Hz
#   音频时长: 10.07秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_156.wav
#   --------------------------------------------------
# 处理: synthesized_speech_157.wav
#   原始采样率: 24000Hz
#   音频时长: 5.59秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_157.wav
#   --------------------------------------------------
# 处理: synthesized_speech_158.wav
#   原始采样率: 24000Hz
#   音频时长: 8.53秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_158.wav
#   --------------------------------------------------
# 处理: synthesized_speech_159.wav
#   原始采样率: 24000Hz
#   音频时长: 3.37秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_159.wav
#   --------------------------------------------------
# 处理: synthesized_speech_160.wav
#   原始采样率: 24000Hz
#   音频时长: 6.23秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_160.wav
#   --------------------------------------------------
# 处理: synthesized_speech_181.wav
#   原始采样率: 24000Hz
#   音频时长: 4.78秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_181.wav
#   --------------------------------------------------
# 处理: synthesized_speech_182.wav
#   原始采样率: 24000Hz
#   音频时长: 4.57秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_182.wav
#   --------------------------------------------------
# 处理: synthesized_speech_183.wav
#   原始采样率: 24000Hz
#   音频时长: 7.00秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_183.wav
#   --------------------------------------------------
# 处理: synthesized_speech_184.wav
#   原始采样率: 24000Hz
#   音频时长: 5.16秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_184.wav
#   --------------------------------------------------
# 处理: synthesized_speech_185.wav
#   原始采样率: 24000Hz
#   音频时长: 8.53秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_185.wav
#   --------------------------------------------------
# 处理: synthesized_speech_186.wav
#   原始采样率: 24000Hz
#   音频时长: 4.52秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_186.wav
#   --------------------------------------------------
# 处理: synthesized_speech_187.wav
#   原始采样率: 24000Hz
#   音频时长: 10.07秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_187.wav
#   --------------------------------------------------
# 处理: synthesized_speech_188.wav
#   原始采样率: 24000Hz
#   音频时长: 9.56秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_188.wav
#   --------------------------------------------------
# 处理: synthesized_speech_189.wav
#   原始采样率: 24000Hz
#   音频时长: 11.48秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_189.wav
#   --------------------------------------------------
# 处理: synthesized_speech_190.wav
#   原始采样率: 24000Hz
#   音频时长: 63.66秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_190.wav
#   --------------------------------------------------
# 处理: synthesized_speech_191.wav
#   原始采样率: 24000Hz
#   音频时长: 4.18秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_191.wav
#   --------------------------------------------------
# 处理: synthesized_speech_192.wav
#   原始采样率: 24000Hz
#   音频时长: 8.15秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_192.wav
#   --------------------------------------------------
# 处理: synthesized_speech_193.wav
#   原始采样率: 24000Hz
#   音频时长: 3.11秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_193.wav
#   --------------------------------------------------
# 处理: synthesized_speech_194.wav
#   原始采样率: 24000Hz
#   音频时长: 0.68秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_194.wav
#   --------------------------------------------------
# 处理: synthesized_speech_195.wav
#   原始采样率: 24000Hz
#   音频时长: 4.57秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_195.wav
#   --------------------------------------------------
# 处理: synthesized_speech_196.wav
#   原始采样率: 24000Hz
#   音频时长: 21.21秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_196.wav
#   --------------------------------------------------
# 处理: synthesized_speech_197.wav
#   原始采样率: 24000Hz
#   音频时长: 3.03秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_197.wav
#   --------------------------------------------------
# 处理: synthesized_speech_198.wav
#   原始采样率: 24000Hz
#   音频时长: 9.30秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_198.wav
#   --------------------------------------------------
# 处理: synthesized_speech_199.wav
#   原始采样率: 24000Hz
#   音频时长: 65.45秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_199.wav
#   --------------------------------------------------
# 处理: synthesized_speech_200.wav
#   原始采样率: 24000Hz
#   音频时长: 7.72秒
#   重采样到: 16000Hz
#   文件已保存: ./old_data/resample/6_output/synthesized_speech_200.wav
#   --------------------------------------------------
# ============================================================
# 处理完成！成功: 200, 失败: 0
# 批量重采样完成！
