# %%
import pandas as pd
import numpy as np
import shutil
import os
from pathlib import Path

def debug_csv_structure(csv_file):
    """
    调试CSV文件结构
    """
    print("=" * 60)
    print("CSV文件结构调试")
    print("=" * 60)
    
    df = pd.read_csv(csv_file)
    print(f"文件: {csv_file}")
    print(f"总行数: {len(df)}")
    print(f"列名: {list(df.columns)}")
    print(f"\n前5行数据:")
    print(df.head())
    print(f"\n数据类型:")
    print(df.dtypes)
    print(f"\n数据统计:")
    print(df.describe())
    
    # 检查特定列的数据
    for col in df.columns:
        if col not in ['index', 'reference_file', 'synthesized_file']:
            print(f"\n列 '{col}' 的详细信息:")
            print(f"  非空值数量: {df[col].count()}")
            print(f"  唯一值示例: {df[col].dropna().unique()[:5]}")
            print(f"  数据类型: {df[col].dtype}")
            
            # 尝试转换数值
            try:
                numeric_col = pd.to_numeric(df[col], errors='coerce')
                print(f"  数值转换后非空值: {numeric_col.count()}")
                print(f"  数值范围: {numeric_col.min():.4f} - {numeric_col.max():.4f}")
            except:
                print(f"  数值转换失败")

def copy_highest_score_audio_fixed(csv_file, folder_mapping, output_dir, start_idx=1, end_idx=200):
    """
    修复版的音频复制程序
    """
    
    # 读取CSV文件
    try:
        df = pd.read_csv(csv_file)
        print(f"成功读取CSV文件: {csv_file}")
        print(f"总行数: {len(df)}")
        print(f"列名: {list(df.columns)}")
    except Exception as e:
        print(f"读取CSV文件失败: {e}")
        return
    
    # 检查列名是否存在于CSV中
    valid_columns = []
    for col in folder_mapping.keys():
        if col in df.columns:
            valid_columns.append(col)
        else:
            print(f"警告: 列 '{col}' 不在CSV文件中，跳过")
    
    if not valid_columns:
        print("错误: 没有有效的列名可供比较")
        return
    
    print(f"有效的对比列: {valid_columns}")
    
    # 强制转换数据类型为数值
    for col in valid_columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')
        print(f"列 '{col}' 转换后有效值数量: {df[col].notna().sum()}")
    
    # 创建输出目录
    os.makedirs(output_dir, exist_ok=True)
    print(f"输出目录: {output_dir}")
    
    # 统计信息
    copy_count = 0
    error_count = 0
    skip_count = 0
    invalid_count = 0
    
    # 处理每一行
    for idx in range(start_idx, end_idx + 1):
        if idx > len(df):
            print(f"警告: 索引 {idx} 超出CSV文件范围")
            break
        
        # 使用iloc按位置索引，避免索引不匹配的问题
        row_idx = idx - 1  # 因为CSV通常从第2行开始（第1行是标题）
        if row_idx < 0 or row_idx >= len(df):
            continue
            
        row = df.iloc[row_idx]
        
        print(f"\n处理索引 {idx} (行 {row_idx + 2}):")
        
        # 获取有效的数值
        valid_scores = {}
        for col in valid_columns:
            value = row[col]
            if pd.notna(value) and isinstance(value, (int, float)) and not np.isnan(value):
                valid_scores[col] = value
                print(f"  {col}: {value:.4f}")
            else:
                print(f"  {col}: 无效值")
        
        # 统计无效值
        if not valid_scores:
            invalid_count += 1
            print(f"  所有值都无效!")
        
        # 确定要复制的文件
        source_file = None
        source_method = ""
        
        if valid_scores:
            # 找到最高分的列
            max_col = max(valid_scores.items(), key=lambda x: x[1])[0]
            source_folder = folder_mapping[max_col]
            source_file = os.path.join(source_folder, f"synthesized_speech_{idx}.wav")
            # source_file = os.path.join(source_folder, f"reference_{idx}.wav")
            source_method = max_col
            print(f"  最高分方法: {max_col}, 分数: {valid_scores[max_col]:.4f}")
        else:
            # 所有值都无效，使用第一栏
            first_col = valid_columns[0]
            source_folder = folder_mapping[first_col]
            source_file = os.path.join(source_folder, f"synthesized_speech_{idx}.wav")
            # source_file = os.path.join(source_folder, f"reference_{idx}.wav")
            source_method = f"{first_col} (默认)"
            print(f"  所有值无效，使用默认方法: {first_col}")
        
        # 检查源文件是否存在
        if source_file and os.path.exists(source_file):
            # 目标文件名
            target_file = os.path.join(output_dir, f"synthesized_speech_{idx}.wav")
            # target_file = os.path.join(output_dir, f"reference_{idx}.wav")
            
            try:
                # 复制文件
                shutil.copy2(source_file, target_file)
                copy_count += 1
                print(f"  ✓ 复制成功: {os.path.basename(source_file)} -> {os.path.basename(target_file)}")
                print(f"  使用方法: {source_method}")
                
            except Exception as e:
                error_count += 1
                print(f"  ✗ 复制失败: {e}")
        else:
            skip_count += 1
            if source_file:
                print(f"  ⚠ 源文件不存在: {os.path.basename(source_file)}")
            else:
                print(f"  ⚠ 源文件路径为空")
    
    # 输出统计信息
    print(f"\n{'='*50}")
    print("处理完成!")
    print(f"{'='*50}")
    print(f"成功复制: {copy_count} 个文件")
    print(f"复制失败: {error_count} 个文件")
    print(f"文件不存在: {skip_count} 个文件")
    print(f"所有值无效: {invalid_count} 个文件")
    print(f"输出目录: {output_dir}")

def check_audio_files_exist(folder_mapping, start_idx=1, end_idx=200):
    """
    检查音频文件是否存在
    """
    print("检查音频文件是否存在...")
    
    for method, folder in folder_mapping.items():
        print(f"\n检查方法: {method}")
        print(f"文件夹: {folder}")
        
        exist_count = 0
        missing_count = 0
        
        for idx in range(start_idx, end_idx + 1):
            file_path = os.path.join(folder, f"synthesized_speech_{idx}.wav")
            # file_path = os.path.join(folder, f"reference_{idx}.wav")
            if os.path.exists(file_path):
                exist_count += 1
            else:
                missing_count += 1
                if missing_count <= 5:  # 只显示前5个缺失文件
                    print(f"  缺失: synthesized_speech_{idx}.wav")
                    # print(f"  缺失: reference_{idx}.wav")
        
        print(f"  存在: {exist_count}, 缺失: {missing_count}")

# 使用示例
if __name__ == "__main__":
    #[可配置]
    # 配置参数
    CSV_FILE = "./output_similarity.csv"
    # CSV_FILE = "./similarity_results.csv"
    
    # 文件夹映射：{'CSV列名': '对应文件夹路径'}
    FOLDER_MAPPING = {
        #输入
        # 'data_deal_816': "../index-tts/data_deal_new/data_deal_816/",
        # '820_enhanced_d_normalized': "../index-tts/data_deal_new/820_enhanced_d_normalized/",
        
        #输出
        # 'data_deal_816_output': "./old_data/compare/data_deal_816_output/",
        '1_output': "./new_data/compare/1_output",
        '2_output': "./new_data/compare/2_output",
        '3_output': "./new_data/compare/3_output",
        '4_output': "./new_data/compare/4_output",
        '5_output': "./new_data/compare/5_output",
        '6_output': "./new_data/compare/6_output",

    }
    OUTPUT_DIR = "./best_audio_results/"
    # OUTPUT_DIR = "./best_audio_enhanced/"
    
    # 首先调试CSV结构
    print("第一步: 调试CSV文件结构")
    debug_csv_structure(CSV_FILE)
    
    print("\n" + "="*60)
    print("第二步: 检查音频文件是否存在")
    check_audio_files_exist(FOLDER_MAPPING, 1, 10)  # 先检查前10个
    
    print("\n" + "="*60)
    print("第三步: 开始复制音频文件")
    copy_highest_score_audio_fixed(CSV_FILE, FOLDER_MAPPING, OUTPUT_DIR, 1, 200)
# Out:
# 第一步: 调试CSV文件结构
# ============================================================
# CSV文件结构调试
# ============================================================
# 文件: ./similarity_results.csv
# 总行数: 200
# 列名: ['index', 'reference_file', 'synthesized_file', 'test_output_16k', 'data_deal_816', '820_enhanced_d_normalized', 'data_deal_816_output', '1_output', '2_output', '3_output', '4_output', '5_output', '6_output', '7_output', '8_output', '9_output']
#
# 前5行数据:
#    index   reference_file            synthesized_file  test_output_16k  \
# 0      1  reference_1.wav  synthesized_speech_1_1.wav           0.4214
# 1      2  reference_2.wav  synthesized_speech_1_2.wav           0.5038
# 2      3  reference_3.wav  synthesized_speech_1_3.wav           0.7536
# 3      4  reference_4.wav  synthesized_speech_1_4.wav           0.7525
# 4      5  reference_5.wav  synthesized_speech_1_5.wav           0.7950
#
#   data_deal_816 820_enhanced_d_normalized data_deal_816_output 1_output  \
# 0        0.9409                    0.9409               0.2136   0.3536
# 1        0.9593                    0.9593               0.4932   0.5078
# 2        0.8676                    0.8676               0.6752     0.67
# 3        0.9344                    0.9346               0.7191   0.6912
# 4        0.9933                    0.9933               0.8139   0.8053
#
#   2_output 3_output 4_output 5_output  6_output  7_output  8_output 9_output
# 0   0.3919   0.4014   0.4356   0.4202    0.4083    0.4408    0.4098   0.3789
# 1   0.4473   0.4994   0.5055   0.4732    0.5019    0.5167    0.4986   0.4777
# 2     0.67   0.6797    0.669   0.6842    0.6756    0.7059    0.6756    0.628
# 3    0.695   0.7182   0.6586   0.7179    0.6977    0.6974    0.7074   0.6875
# 4    0.812   0.8026   0.8047   0.7987    0.8058    0.8040    0.8130   0.8177
#
# 数据类型:
# index                          int64
# reference_file                object
# synthesized_file              object
# test_output_16k              float64
# data_deal_816                 object
# 820_enhanced_d_normalized     object
# data_deal_816_output          object
# 1_output                      object
# 2_output                      object
# 3_output                      object
# 4_output                      object
# 5_output                      object
# 6_output                     float64
# 7_output                     float64
# 8_output                     float64
# 9_output                      object
# dtype: object
#
# 数据统计:
#             index  test_output_16k    6_output    7_output    8_output
# count  200.000000       200.000000  200.000000  200.000000  198.000000
# mean   100.500000         0.773686    0.718088    0.717727    0.718245
# std     57.879185         0.084837    0.112021    0.112971    0.111604
# min      1.000000         0.321500    0.371700    0.358800    0.355300
# 25%     50.750000         0.737750    0.663500    0.655550    0.656175
# 50%    100.500000         0.793450    0.746350    0.737550    0.739600
# 75%    150.250000         0.829425    0.804050    0.800575    0.801525
# max    200.000000         0.907700    0.898700    0.897600    0.897000
#
# 列 'test_output_16k' 的详细信息:
#   非空值数量: 200
#   唯一值示例: [0.4214 0.5038 0.7536 0.7525 0.795 ]
#   数据类型: float64
#   数值转换后非空值: 200
#   数值范围: 0.3215 - 0.9077
#
# 列 'data_deal_816' 的详细信息:
#   非空值数量: 200
#   唯一值示例: ['0.9409' '0.9593' '0.8676' '0.9344' '0.9933']
#   数据类型: object
#   数值转换后非空值: 195
#   数值范围: 0.3991 - 0.9984
#
# 列 '820_enhanced_d_normalized' 的详细信息:
#   非空值数量: 200
#   唯一值示例: ['0.9409' '0.9593' '0.8676' '0.9346' '0.9933']
#   数据类型: object
#   数值转换后非空值: 198
#   数值范围: 0.3991 - 0.9984
#
# 列 'data_deal_816_output' 的详细信息:
#   非空值数量: 200
#   唯一值示例: ['0.2136' '0.4932' '0.6752' '0.7191' '0.8139']
#   数据类型: object
#   数值转换后非空值: 197
#   数值范围: 0.2136 - 0.8972
#
# 列 '1_output' 的详细信息:
#   非空值数量: 200
#   唯一值示例: ['0.3536' '0.5078' '0.67' '0.6912' '0.8053']
#   数据类型: object
#   数值转换后非空值: 189
#   数值范围: 0.3183 - 0.8826
#
# 列 '2_output' 的详细信息:
#   非空值数量: 200
#   唯一值示例: ['0.3919' '0.4473' '0.67' '0.695' '0.812']
#   数据类型: object
#   数值转换后非空值: 193
#   数值范围: 0.3378 - 0.8884
#
# 列 '3_output' 的详细信息:
#   非空值数量: 200
#   唯一值示例: ['0.4014' '0.4994' '0.6797' '0.7182' '0.8026']
#   数据类型: object
#   数值转换后非空值: 197
#   数值范围: 0.3495 - 0.9165
#
# 列 '4_output' 的详细信息:
#   非空值数量: 200
#   唯一值示例: ['0.4356' '0.5055' '0.669' '0.6586' '0.8047']
#   数据类型: object
#   数值转换后非空值: 197
#   数值范围: 0.3564 - 0.8987
#
# 列 '5_output' 的详细信息:
#   非空值数量: 200
#   唯一值示例: ['0.4202' '0.4732' '0.6842' '0.7179' '0.7987']
#   数据类型: object
#   数值转换后非空值: 198
#   数值范围: 0.3622 - 0.9013
#
# 列 '6_output' 的详细信息:
#   非空值数量: 200
#   唯一值示例: [0.4083 0.5019 0.6756 0.6977 0.8058]
#   数据类型: float64
#   数值转换后非空值: 200
#   数值范围: 0.3717 - 0.8987
#
# 列 '7_output' 的详细信息:
#   非空值数量: 200
#   唯一值示例: [0.4408 0.5167 0.7059 0.6974 0.804 ]
#   数据类型: float64
#   数值转换后非空值: 200
#   数值范围: 0.3588 - 0.8976
#
# 列 '8_output' 的详细信息:
#   非空值数量: 198
#   唯一值示例: [0.4098 0.4986 0.6756 0.7074 0.813 ]
#   数据类型: float64
#   数值转换后非空值: 198
#   数值范围: 0.3553 - 0.8970
#
# 列 '9_output' 的详细信息:
#   非空值数量: 199
#   唯一值示例: ['0.3789' '0.4777' '0.628' '0.6875' '0.8177']
#   数据类型: object
#   数值转换后非空值: 197
#   数值范围: 0.3506 - 0.8999
#
# ============================================================
# 第二步: 检查音频文件是否存在
# 检查音频文件是否存在...
#
# 检查方法: data_deal_816_output
# 文件夹: ./old_data/compare/data_deal_816_output/
#   存在: 10, 缺失: 0
#
# 检查方法: 1_output
# 文件夹: ./old_data/compare/1_output
#   存在: 10, 缺失: 0
#
# 检查方法: 2_output
# 文件夹: ./old_data/compare/2_output
#   存在: 10, 缺失: 0
#
# 检查方法: 3_output
# 文件夹: ./old_data/compare/3_output
#   存在: 10, 缺失: 0
#
# 检查方法: 4_output
# 文件夹: ./old_data/compare/4_output
#   存在: 10, 缺失: 0
#
# 检查方法: 5_output
# 文件夹: ./old_data/compare/5_output
#   存在: 10, 缺失: 0
#
# 检查方法: 6_output
# 文件夹: ./old_data/compare/6_output
#   存在: 10, 缺失: 0
#
# ============================================================
# 第三步: 开始复制音频文件
# 成功读取CSV文件: ./similarity_results.csv
# 总行数: 200
# 列名: ['index', 'reference_file', 'synthesized_file', 'test_output_16k', 'data_deal_816', '820_enhanced_d_normalized', 'data_deal_816_output', '1_output', '2_output', '3_output', '4_output', '5_output', '6_output', '7_output', '8_output', '9_output']
# 有效的对比列: ['data_deal_816_output', '1_output', '2_output', '3_output', '4_output', '5_output', '6_output']
# 列 'data_deal_816_output' 转换后有效值数量: 197
# 列 '1_output' 转换后有效值数量: 189
# 列 '2_output' 转换后有效值数量: 193
# 列 '3_output' 转换后有效值数量: 197
# 列 '4_output' 转换后有效值数量: 197
# 列 '5_output' 转换后有效值数量: 198
# 列 '6_output' 转换后有效值数量: 200
# 输出目录: ./best_audio_results/
#
# 处理索引 1 (行 2):
#   data_deal_816_output: 0.2136
#   1_output: 0.3536
#   2_output: 0.3919
#   3_output: 0.4014
#   4_output: 0.4356
#   5_output: 0.4202
#   6_output: 0.4083
#   最高分方法: 4_output, 分数: 0.4356
#   ✓ 复制成功: synthesized_speech_1.wav -> synthesized_speech_1.wav
#   使用方法: 4_output
#
# 处理索引 2 (行 3):
#   data_deal_816_output: 0.4932
#   1_output: 0.5078
#   2_output: 0.4473
#   3_output: 0.4994
#   4_output: 0.5055
#   5_output: 0.4732
#   6_output: 0.5019
#   最高分方法: 1_output, 分数: 0.5078
#   ✓ 复制成功: synthesized_speech_2.wav -> synthesized_speech_2.wav
#   使用方法: 1_output
#
# 处理索引 3 (行 4):
#   data_deal_816_output: 0.6752
#   1_output: 0.6700
#   2_output: 0.6700
#   3_output: 0.6797
#   4_output: 0.6690
#   5_output: 0.6842
#   6_output: 0.6756
#   最高分方法: 5_output, 分数: 0.6842
#   ✓ 复制成功: synthesized_speech_3.wav -> synthesized_speech_3.wav
#   使用方法: 5_output
#
# 处理索引 4 (行 5):
#   data_deal_816_output: 0.7191
#   1_output: 0.6912
#   2_output: 0.6950
#   3_output: 0.7182
#   4_output: 0.6586
#   5_output: 0.7179
#   6_output: 0.6977
#   最高分方法: data_deal_816_output, 分数: 0.7191
#   ✓ 复制成功: synthesized_speech_4.wav -> synthesized_speech_4.wav
#   使用方法: data_deal_816_output
#
# 处理索引 5 (行 6):
#   data_deal_816_output: 0.8139
#   1_output: 0.8053
#   2_output: 0.8120
#   3_output: 0.8026
#   4_output: 0.8047
#   5_output: 0.7987
#   6_output: 0.8058
#   最高分方法: data_deal_816_output, 分数: 0.8139
#   ✓ 复制成功: synthesized_speech_5.wav -> synthesized_speech_5.wav
#   使用方法: data_deal_816_output
#
# 处理索引 6 (行 7):
#   data_deal_816_output: 0.7636
#   1_output: 0.7585
#   2_output: 0.7822
#   3_output: 0.7793
#   4_output: 0.7717
#   5_output: 0.7767
#   6_output: 0.7764
#   最高分方法: 2_output, 分数: 0.7822
#   ✓ 复制成功: synthesized_speech_6.wav -> synthesized_speech_6.wav
#   使用方法: 2_output
#
# 处理索引 7 (行 8):
#   data_deal_816_output: 0.6502
#   1_output: 0.6229
#   2_output: 0.5986
#   3_output: 0.6327
#   4_output: 0.6376
#   5_output: 0.6392
#   6_output: 0.6395
#   最高分方法: data_deal_816_output, 分数: 0.6502
#   ✓ 复制成功: synthesized_speech_7.wav -> synthesized_speech_7.wav
#   使用方法: data_deal_816_output
#
# 处理索引 8 (行 9):
#   data_deal_816_output: 0.6215
#   1_output: 0.6080
#   2_output: 0.6528
#   3_output: 0.6077
#   4_output: 0.5627
#   5_output: 0.5982
#   6_output: 0.5785
#   最高分方法: 2_output, 分数: 0.6528
#   ✓ 复制成功: synthesized_speech_8.wav -> synthesized_speech_8.wav
#   使用方法: 2_output
#
# 处理索引 9 (行 10):
#   data_deal_816_output: 0.8396
#   1_output: 0.8293
#   2_output: 0.8460
#   3_output: 0.8454
#   4_output: 0.8536
#   5_output: 0.8522
#   6_output: 0.8355
#   最高分方法: 4_output, 分数: 0.8536
#   ✓ 复制成功: synthesized_speech_9.wav -> synthesized_speech_9.wav
#   使用方法: 4_output
#
# 处理索引 10 (行 11):
#   data_deal_816_output: 0.7829
#   1_output: 0.7812
#   2_output: 0.7780
#   3_output: 0.7651
#   4_output: 0.7744
#   5_output: 0.7682
#   6_output: 0.7657
#   最高分方法: data_deal_816_output, 分数: 0.7829
#   ✓ 复制成功: synthesized_speech_10.wav -> synthesized_speech_10.wav
#   使用方法: data_deal_816_output
#
# 处理索引 11 (行 12):
#   data_deal_816_output: 0.7786
#   1_output: 0.8030
#   2_output: 0.7800
#   3_output: 0.8139
#   4_output: 0.8033
#   5_output: 0.8065
#   6_output: 0.8072
#   最高分方法: 3_output, 分数: 0.8139
#   ✓ 复制成功: synthesized_speech_11.wav -> synthesized_speech_11.wav
#   使用方法: 3_output
#
# 处理索引 12 (行 13):
#   data_deal_816_output: 0.8570
#   1_output: 0.8406
#   2_output: 0.8604
#   3_output: 0.8549
#   4_output: 0.8529
#   5_output: 0.8609
#   6_output: 0.8723
#   最高分方法: 6_output, 分数: 0.8723
#   ✓ 复制成功: synthesized_speech_12.wav -> synthesized_speech_12.wav
#   使用方法: 6_output
#
# 处理索引 13 (行 14):
#   data_deal_816_output: 0.7468
#   1_output: 0.7731
#   2_output: 0.7550
#   3_output: 0.7468
#   4_output: 0.7605
#   5_output: 0.7705
#   6_output: 0.7708
#   最高分方法: 1_output, 分数: 0.7731
#   ✓ 复制成功: synthesized_speech_13.wav -> synthesized_speech_13.wav
#   使用方法: 1_output
#
# 处理索引 14 (行 15):
#   data_deal_816_output: 0.8439
#   1_output: 0.8257
#   2_output: 0.8432
#   3_output: 0.7994
#   4_output: 0.8313
#   5_output: 0.8398
#   6_output: 0.8160
#   最高分方法: data_deal_816_output, 分数: 0.8439
#   ✓ 复制成功: synthesized_speech_14.wav -> synthesized_speech_14.wav
#   使用方法: data_deal_816_output
#
# 处理索引 15 (行 16):
#   data_deal_816_output: 0.6709
#   1_output: 0.6494
#   2_output: 0.6613
#   3_output: 0.6745
#   4_output: 0.6578
#   5_output: 0.6928
#   6_output: 0.7057
#   最高分方法: 6_output, 分数: 0.7057
#   ✓ 复制成功: synthesized_speech_15.wav -> synthesized_speech_15.wav
#   使用方法: 6_output
#
# 处理索引 16 (行 17):
#   data_deal_816_output: 0.7300
#   1_output: 0.7099
#   2_output: 0.7284
#   3_output: 0.7268
#   4_output: 0.7108
#   5_output: 0.7108
#   6_output: 0.7213
#   最高分方法: data_deal_816_output, 分数: 0.7300
#   ✓ 复制成功: synthesized_speech_16.wav -> synthesized_speech_16.wav
#   使用方法: data_deal_816_output
#
# 处理索引 17 (行 18):
#   data_deal_816_output: 0.8568
#   1_output: 0.8557
#   2_output: 0.8597
#   3_output: 0.8688
#   4_output: 0.8528
#   5_output: 0.8684
#   6_output: 0.8467
#   最高分方法: 3_output, 分数: 0.8688
#   ✓ 复制成功: synthesized_speech_17.wav -> synthesized_speech_17.wav
#   使用方法: 3_output
#
# 处理索引 18 (行 19):
#   data_deal_816_output: 0.5885
#   1_output: 0.6030
#   2_output: 0.5916
#   3_output: 0.6101
#   4_output: 0.6355
#   5_output: 0.5811
#   6_output: 0.6125
#   最高分方法: 4_output, 分数: 0.6355
#   ✓ 复制成功: synthesized_speech_18.wav -> synthesized_speech_18.wav
#   使用方法: 4_output
#
# 处理索引 19 (行 20):
#   data_deal_816_output: 0.7568
#   1_output: 0.7469
#   2_output: 0.7499
#   3_output: 0.7620
#   4_output: 0.7613
#   5_output: 0.7569
#   6_output: 0.7425
#   最高分方法: 3_output, 分数: 0.7620
#   ✓ 复制成功: synthesized_speech_19.wav -> synthesized_speech_19.wav
#   使用方法: 3_output
#
# 处理索引 20 (行 21):
#   data_deal_816_output: 0.6580
#   1_output: 0.6844
#   2_output: 0.6936
#   3_output: 0.6700
#   4_output: 0.6724
#   5_output: 0.6759
#   6_output: 0.6802
#   最高分方法: 2_output, 分数: 0.6936
#   ✓ 复制成功: synthesized_speech_20.wav -> synthesized_speech_20.wav
#   使用方法: 2_output
#
# 处理索引 21 (行 22):
#   data_deal_816_output: 0.6835
#   1_output: 0.6744
#   2_output: 0.6506
#   3_output: 0.7025
#   4_output: 0.6680
#   5_output: 0.6455
#   6_output: 0.6824
#   最高分方法: 3_output, 分数: 0.7025
#   ✓ 复制成功: synthesized_speech_21.wav -> synthesized_speech_21.wav
#   使用方法: 3_output
#
# 处理索引 22 (行 23):
#   data_deal_816_output: 0.7888
#   1_output: 0.7304
#   2_output: 0.7686
#   3_output: 0.7187
#   4_output: 0.7103
#   5_output: 0.7295
#   6_output: 0.7083
#   最高分方法: data_deal_816_output, 分数: 0.7888
#   ✓ 复制成功: synthesized_speech_22.wav -> synthesized_speech_22.wav
#   使用方法: data_deal_816_output
#
# 处理索引 23 (行 24):
#   data_deal_816_output: 0.5923
#   1_output: 0.6333
#   2_output: 0.6445
#   3_output: 0.6440
#   4_output: 0.6106
#   5_output: 0.6304
#   6_output: 0.6430
#   最高分方法: 2_output, 分数: 0.6445
#   ✓ 复制成功: synthesized_speech_23.wav -> synthesized_speech_23.wav
#   使用方法: 2_output
#
# 处理索引 24 (行 25):
#   data_deal_816_output: 0.6541
#   1_output: 0.6929
#   2_output: 0.6860
#   3_output: 0.6764
#   4_output: 0.6886
#   5_output: 0.6823
#   6_output: 0.6861
#   最高分方法: 1_output, 分数: 0.6929
#   ✓ 复制成功: synthesized_speech_24.wav -> synthesized_speech_24.wav
#   使用方法: 1_output
#
# 处理索引 25 (行 26):
#   data_deal_816_output: 0.7097
#   1_output: 0.7086
#   2_output: 0.7174
#   3_output: 0.7325
#   4_output: 0.7364
#   5_output: 0.7091
#   6_output: 0.6881
#   最高分方法: 4_output, 分数: 0.7364
#   ✓ 复制成功: synthesized_speech_25.wav -> synthesized_speech_25.wav
#   使用方法: 4_output
#
# 处理索引 26 (行 27):
#   data_deal_816_output: 0.8464
#   1_output: 0.8380
#   2_output: 无效值
#   3_output: 0.8249
#   4_output: 0.8322
#   5_output: 0.8219
#   6_output: 0.8321
#   最高分方法: data_deal_816_output, 分数: 0.8464
#   ✓ 复制成功: synthesized_speech_26.wav -> synthesized_speech_26.wav
#   使用方法: data_deal_816_output
#
# 处理索引 27 (行 28):
#   data_deal_816_output: 0.7814
#   1_output: 0.7865
#   2_output: 0.7732
#   3_output: 0.7772
#   4_output: 0.7804
#   5_output: 0.7792
#   6_output: 0.7880
#   最高分方法: 6_output, 分数: 0.7880
#   ✓ 复制成功: synthesized_speech_27.wav -> synthesized_speech_27.wav
#   使用方法: 6_output
#
# 处理索引 28 (行 29):
#   data_deal_816_output: 0.6294
#   1_output: 0.6328
#   2_output: 0.6132
#   3_output: 0.6263
#   4_output: 0.6223
#   5_output: 0.6017
#   6_output: 0.6111
#   最高分方法: 1_output, 分数: 0.6328
#   ✓ 复制成功: synthesized_speech_28.wav -> synthesized_speech_28.wav
#   使用方法: 1_output
#
# 处理索引 29 (行 30):
#   data_deal_816_output: 0.5565
#   1_output: 0.6118
#   2_output: 0.5694
#   3_output: 0.5885
#   4_output: 0.6003
#   5_output: 0.5877
#   6_output: 0.5857
#   最高分方法: 1_output, 分数: 0.6118
#   ✓ 复制成功: synthesized_speech_29.wav -> synthesized_speech_29.wav
#   使用方法: 1_output
#
# 处理索引 30 (行 31):
#   data_deal_816_output: 0.8533
#   1_output: 0.8522
#   2_output: 0.8424
#   3_output: 0.8572
#   4_output: 0.8524
#   5_output: 0.8431
#   6_output: 0.8436
#   最高分方法: 3_output, 分数: 0.8572
#   ✓ 复制成功: synthesized_speech_30.wav -> synthesized_speech_30.wav
#   使用方法: 3_output
#
# 处理索引 31 (行 32):
#   data_deal_816_output: 0.8021
#   1_output: 0.7633
#   2_output: 0.7723
#   3_output: 0.7713
#   4_output: 0.7653
#   5_output: 0.7656
#   6_output: 0.7615
#   最高分方法: data_deal_816_output, 分数: 0.8021
#   ✓ 复制成功: synthesized_speech_31.wav -> synthesized_speech_31.wav
#   使用方法: data_deal_816_output
#
# 处理索引 32 (行 33):
#   data_deal_816_output: 0.8605
#   1_output: 0.8458
#   2_output: 0.8122
#   3_output: 0.8480
#   4_output: 0.8598
#   5_output: 0.8489
#   6_output: 0.8553
#   最高分方法: data_deal_816_output, 分数: 0.8605
#   ✓ 复制成功: synthesized_speech_32.wav -> synthesized_speech_32.wav
#   使用方法: data_deal_816_output
#
# 处理索引 33 (行 34):
#   data_deal_816_output: 0.8359
#   1_output: 0.8176
#   2_output: 0.8371
#   3_output: 0.8324
#   4_output: 0.8196
#   5_output: 0.8283
#   6_output: 0.8299
#   最高分方法: 2_output, 分数: 0.8371
#   ✓ 复制成功: synthesized_speech_33.wav -> synthesized_speech_33.wav
#   使用方法: 2_output
#
# 处理索引 34 (行 35):
#   data_deal_816_output: 0.5946
#   1_output: 0.5977
#   2_output: 0.5968
#   3_output: 0.5798
#   4_output: 0.5875
#   5_output: 0.5769
#   6_output: 0.6327
#   最高分方法: 6_output, 分数: 0.6327
#   ✓ 复制成功: synthesized_speech_34.wav -> synthesized_speech_34.wav
#   使用方法: 6_output
#
# 处理索引 35 (行 36):
#   data_deal_816_output: 0.6632
#   1_output: 0.6802
#   2_output: 0.6909
#   3_output: 0.6228
#   4_output: 0.6756
#   5_output: 0.6839
#   6_output: 0.6841
#   最高分方法: 2_output, 分数: 0.6909
#   ✓ 复制成功: synthesized_speech_35.wav -> synthesized_speech_35.wav
#   使用方法: 2_output
#
# 处理索引 36 (行 37):
#   data_deal_816_output: 0.7783
#   1_output: 0.7934
#   2_output: 0.7866
#   3_output: 0.7969
#   4_output: 0.7841
#   5_output: 0.7854
#   6_output: 0.8040
#   最高分方法: 6_output, 分数: 0.8040
#   ✓ 复制成功: synthesized_speech_36.wav -> synthesized_speech_36.wav
#   使用方法: 6_output
#
# 处理索引 37 (行 38):
#   data_deal_816_output: 0.6567
#   1_output: 0.6536
#   2_output: 0.6586
#   3_output: 0.6797
#   4_output: 0.6566
#   5_output: 0.6765
#   6_output: 0.6613
#   最高分方法: 3_output, 分数: 0.6797
#   ✓ 复制成功: synthesized_speech_37.wav -> synthesized_speech_37.wav
#   使用方法: 3_output
#
# 处理索引 38 (行 39):
#   data_deal_816_output: 0.7011
#   1_output: 0.7640
#   2_output: 0.7549
#   3_output: 0.7868
#   4_output: 0.7666
#   5_output: 0.7580
#   6_output: 0.7659
#   最高分方法: 3_output, 分数: 0.7868
#   ✓ 复制成功: synthesized_speech_38.wav -> synthesized_speech_38.wav
#   使用方法: 3_output
#
# 处理索引 39 (行 40):
#   data_deal_816_output: 0.7628
#   1_output: 0.7572
#   2_output: 0.7627
#   3_output: 0.7656
#   4_output: 0.7485
#   5_output: 0.7678
#   6_output: 0.7780
#   最高分方法: 6_output, 分数: 0.7780
#   ✓ 复制成功: synthesized_speech_39.wav -> synthesized_speech_39.wav
#   使用方法: 6_output
#
# 处理索引 40 (行 41):
#   data_deal_816_output: 0.6084
#   1_output: 0.6258
#   2_output: 0.6569
#   3_output: 0.6319
#   4_output: 0.6671
#   5_output: 0.6385
#   6_output: 0.6461
#   最高分方法: 4_output, 分数: 0.6671
#   ✓ 复制成功: synthesized_speech_40.wav -> synthesized_speech_40.wav
#   使用方法: 4_output
#
# 处理索引 41 (行 42):
#   data_deal_816_output: 0.7416
#   1_output: 0.7361
#   2_output: 0.7723
#   3_output: 0.7732
#   4_output: 0.7372
#   5_output: 0.7462
#   6_output: 0.7476
#   最高分方法: 3_output, 分数: 0.7732
#   ✓ 复制成功: synthesized_speech_41.wav -> synthesized_speech_41.wav
#   使用方法: 3_output
#
# 处理索引 42 (行 43):
#   data_deal_816_output: 0.5081
#   1_output: 0.4762
#   2_output: 0.4739
#   3_output: 0.4523
#   4_output: 0.4484
#   5_output: 0.4690
#   6_output: 0.4976
#   最高分方法: data_deal_816_output, 分数: 0.5081
#   ✓ 复制成功: synthesized_speech_42.wav -> synthesized_speech_42.wav
#   使用方法: data_deal_816_output
#
# 处理索引 43 (行 44):
#   data_deal_816_output: 0.8222
#   1_output: 0.8323
#   2_output: 0.8277
#   3_output: 0.8435
#   4_output: 0.8364
#   5_output: 0.8252
#   6_output: 0.8128
#   最高分方法: 3_output, 分数: 0.8435
#   ✓ 复制成功: synthesized_speech_43.wav -> synthesized_speech_43.wav
#   使用方法: 3_output
#
# 处理索引 44 (行 45):
#   data_deal_816_output: 0.4360
#   1_output: 无效值
#   2_output: 0.4122
#   3_output: 0.4486
#   4_output: 0.4360
#   5_output: 0.4510
#   6_output: 0.4113
#   最高分方法: 5_output, 分数: 0.4510
#   ✓ 复制成功: synthesized_speech_44.wav -> synthesized_speech_44.wav
#   使用方法: 5_output
#
# 处理索引 45 (行 46):
#   data_deal_816_output: 0.7422
#   1_output: 0.7655
#   2_output: 0.7610
#   3_output: 0.7560
#   4_output: 0.7347
#   5_output: 0.7813
#   6_output: 0.7740
#   最高分方法: 5_output, 分数: 0.7813
#   ✓ 复制成功: synthesized_speech_45.wav -> synthesized_speech_45.wav
#   使用方法: 5_output
#
# 处理索引 46 (行 47):
#   data_deal_816_output: 0.7586
#   1_output: 0.7920
#   2_output: 0.7928
#   3_output: 0.8052
#   4_output: 0.8208
#   5_output: 0.8088
#   6_output: 0.7762
#   最高分方法: 4_output, 分数: 0.8208
#   ✓ 复制成功: synthesized_speech_46.wav -> synthesized_speech_46.wav
#   使用方法: 4_output
#
# 处理索引 47 (行 48):
#   data_deal_816_output: 0.6769
#   1_output: 0.6420
#   2_output: 0.6691
#   3_output: 0.6830
#   4_output: 0.6557
#   5_output: 0.6593
#   6_output: 0.6432
#   最高分方法: 3_output, 分数: 0.6830
#   ✓ 复制成功: synthesized_speech_47.wav -> synthesized_speech_47.wav
#   使用方法: 3_output
#
# 处理索引 48 (行 49):
#   data_deal_816_output: 0.8413
#   1_output: 0.8453
#   2_output: 0.8392
#   3_output: 0.8316
#   4_output: 0.8412
#   5_output: 0.8367
#   6_output: 0.8362
#   最高分方法: 1_output, 分数: 0.8453
#   ✓ 复制成功: synthesized_speech_48.wav -> synthesized_speech_48.wav
#   使用方法: 1_output
#
# 处理索引 49 (行 50):
#   data_deal_816_output: 0.7102
#   1_output: 0.7694
#   2_output: 0.7410
#   3_output: 0.7561
#   4_output: 0.7472
#   5_output: 0.7453
#   6_output: 0.7432
#   最高分方法: 1_output, 分数: 0.7694
#   ✓ 复制成功: synthesized_speech_49.wav -> synthesized_speech_49.wav
#   使用方法: 1_output
#
# 处理索引 50 (行 51):
#   data_deal_816_output: 0.8248
#   1_output: 0.8089
#   2_output: 0.7949
#   3_output: 0.8118
#   4_output: 0.8236
#   5_output: 0.8153
#   6_output: 0.8011
#   最高分方法: data_deal_816_output, 分数: 0.8248
#   ✓ 复制成功: synthesized_speech_50.wav -> synthesized_speech_50.wav
#   使用方法: data_deal_816_output
#
# 处理索引 51 (行 52):
#   data_deal_816_output: 0.6580
#   1_output: 0.7217
#   2_output: 0.6976
#   3_output: 0.6481
#   4_output: 0.6796
#   5_output: 0.6927
#   6_output: 0.6693
#   最高分方法: 1_output, 分数: 0.7217
#   ✓ 复制成功: synthesized_speech_51.wav -> synthesized_speech_51.wav
#   使用方法: 1_output
#
# 处理索引 52 (行 53):
#   data_deal_816_output: 0.7576
#   1_output: 0.7536
#   2_output: 0.7557
#   3_output: 0.7643
#   4_output: 0.7703
#   5_output: 0.7692
#   6_output: 0.7661
#   最高分方法: 4_output, 分数: 0.7703
#   ✓ 复制成功: synthesized_speech_52.wav -> synthesized_speech_52.wav
#   使用方法: 4_output
#
# 处理索引 53 (行 54):
#   data_deal_816_output: 0.7374
#   1_output: 0.6980
#   2_output: 0.6710
#   3_output: 0.7293
#   4_output: 0.6813
#   5_output: 0.6832
#   6_output: 0.6581
#   最高分方法: data_deal_816_output, 分数: 0.7374
#   ✓ 复制成功: synthesized_speech_53.wav -> synthesized_speech_53.wav
#   使用方法: data_deal_816_output
#
# 处理索引 54 (行 55):
#   data_deal_816_output: 0.5146
#   1_output: 0.5318
#   2_output: 0.5128
#   3_output: 0.5549
#   4_output: 0.5447
#   5_output: 0.5384
#   6_output: 0.5225
#   最高分方法: 3_output, 分数: 0.5549
#   ✓ 复制成功: synthesized_speech_54.wav -> synthesized_speech_54.wav
#   使用方法: 3_output
#
# 处理索引 55 (行 56):
#   data_deal_816_output: 0.8762
#   1_output: 0.8772
#   2_output: 0.8582
#   3_output: 0.8846
#   4_output: 0.8758
#   5_output: 0.8765
#   6_output: 0.8867
#   最高分方法: 6_output, 分数: 0.8867
#   ✓ 复制成功: synthesized_speech_55.wav -> synthesized_speech_55.wav
#   使用方法: 6_output
#
# 处理索引 56 (行 57):
#   data_deal_816_output: 0.8279
#   1_output: 0.8325
#   2_output: 0.8342
#   3_output: 0.8225
#   4_output: 0.8359
#   5_output: 0.8143
#   6_output: 0.8373
#   最高分方法: 6_output, 分数: 0.8373
#   ✓ 复制成功: synthesized_speech_56.wav -> synthesized_speech_56.wav
#   使用方法: 6_output
#
# 处理索引 57 (行 58):
#   data_deal_816_output: 0.7982
#   1_output: 无效值
#   2_output: 0.7910
#   3_output: 0.8152
#   4_output: 0.7797
#   5_output: 0.7688
#   6_output: 0.7961
#   最高分方法: 3_output, 分数: 0.8152
#   ✓ 复制成功: synthesized_speech_57.wav -> synthesized_speech_57.wav
#   使用方法: 3_output
#
# 处理索引 58 (行 59):
#   data_deal_816_output: 0.7116
#   1_output: 0.7150
#   2_output: 0.7195
#   3_output: 0.7192
#   4_output: 0.7304
#   5_output: 0.7009
#   6_output: 0.7369
#   最高分方法: 6_output, 分数: 0.7369
#   ✓ 复制成功: synthesized_speech_58.wav -> synthesized_speech_58.wav
#   使用方法: 6_output
#
# 处理索引 59 (行 60):
#   data_deal_816_output: 0.7660
#   1_output: 0.7828
#   2_output: 0.7896
#   3_output: 0.7876
#   4_output: 0.7961
#   5_output: 0.7977
#   6_output: 0.7872
#   最高分方法: 5_output, 分数: 0.7977
#   ✓ 复制成功: synthesized_speech_59.wav -> synthesized_speech_59.wav
#   使用方法: 5_output
#
# 处理索引 60 (行 61):
#   data_deal_816_output: 0.5850
#   1_output: 0.6142
#   2_output: 0.5989
#   3_output: 0.6266
#   4_output: 0.6104
#   5_output: 0.6259
#   6_output: 0.6026
#   最高分方法: 3_output, 分数: 0.6266
#   ✓ 复制成功: synthesized_speech_60.wav -> synthesized_speech_60.wav
#   使用方法: 3_output
#
# 处理索引 61 (行 62):
#   data_deal_816_output: 0.6531
#   1_output: 0.6690
#   2_output: 0.6710
#   3_output: 0.6661
#   4_output: 0.6213
#   5_output: 0.6475
#   6_output: 0.6707
#   最高分方法: 2_output, 分数: 0.6710
#   ✓ 复制成功: synthesized_speech_61.wav -> synthesized_speech_61.wav
#   使用方法: 2_output
#
# 处理索引 62 (行 63):
#   data_deal_816_output: 0.8565
#   1_output: 0.8556
#   2_output: 0.8524
#   3_output: 0.8467
#   4_output: 0.8378
#   5_output: 0.8421
#   6_output: 0.8420
#   最高分方法: data_deal_816_output, 分数: 0.8565
#   ✓ 复制成功: synthesized_speech_62.wav -> synthesized_speech_62.wav
#   使用方法: data_deal_816_output
#
# 处理索引 63 (行 64):
#   data_deal_816_output: 0.7916
#   1_output: 0.7955
#   2_output: 0.7764
#   3_output: 0.7617
#   4_output: 0.7887
#   5_output: 0.7776
#   6_output: 0.7957
#   最高分方法: 6_output, 分数: 0.7957
#   ✓ 复制成功: synthesized_speech_63.wav -> synthesized_speech_63.wav
#   使用方法: 6_output
#
# 处理索引 64 (行 65):
#   data_deal_816_output: 0.6927
#   1_output: 0.6959
#   2_output: 0.6739
#   3_output: 0.6627
#   4_output: 0.7048
#   5_output: 0.7101
#   6_output: 0.6909
#   最高分方法: 5_output, 分数: 0.7101
#   ✓ 复制成功: synthesized_speech_64.wav -> synthesized_speech_64.wav
#   使用方法: 5_output
#
# 处理索引 65 (行 66):
#   data_deal_816_output: 0.6869
#   1_output: 0.6244
#   2_output: 0.6274
#   3_output: 0.6276
#   4_output: 0.6493
#   5_output: 0.6396
#   6_output: 0.6395
#   最高分方法: data_deal_816_output, 分数: 0.6869
#   ✓ 复制成功: synthesized_speech_65.wav -> synthesized_speech_65.wav
#   使用方法: data_deal_816_output
#
# 处理索引 66 (行 67):
#   data_deal_816_output: 0.4591
#   1_output: 0.4845
#   2_output: 0.4883
#   3_output: 0.4825
#   4_output: 0.4622
#   5_output: 0.4588
#   6_output: 0.4758
#   最高分方法: 2_output, 分数: 0.4883
#   ✓ 复制成功: synthesized_speech_66.wav -> synthesized_speech_66.wav
#   使用方法: 2_output
#
# 处理索引 67 (行 68):
#   data_deal_816_output: 0.5533
#   1_output: 0.5649
#   2_output: 0.5629
#   3_output: 0.5584
#   4_output: 0.5705
#   5_output: 0.5728
#   6_output: 0.5575
#   最高分方法: 5_output, 分数: 0.5728
#   ✓ 复制成功: synthesized_speech_67.wav -> synthesized_speech_67.wav
#   使用方法: 5_output
#
# 处理索引 68 (行 69):
#   data_deal_816_output: 0.7667
#   1_output: 0.7699
#   2_output: 0.7458
#   3_output: 0.7651
#   4_output: 0.7708
#   5_output: 0.7701
#   6_output: 0.7669
#   最高分方法: 4_output, 分数: 0.7708
#   ✓ 复制成功: synthesized_speech_68.wav -> synthesized_speech_68.wav
#   使用方法: 4_output
#
# 处理索引 69 (行 70):
#   data_deal_816_output: 0.8684
#   1_output: 0.8638
#   2_output: 0.8609
#   3_output: 0.8576
#   4_output: 0.8613
#   5_output: 0.8580
#   6_output: 0.8656
#   最高分方法: data_deal_816_output, 分数: 0.8684
#   ✓ 复制成功: synthesized_speech_69.wav -> synthesized_speech_69.wav
#   使用方法: data_deal_816_output
#
# 处理索引 70 (行 71):
#   data_deal_816_output: 0.7611
#   1_output: 0.7739
#   2_output: 0.7686
#   3_output: 0.7381
#   4_output: 0.7587
#   5_output: 0.7732
#   6_output: 0.7605
#   最高分方法: 1_output, 分数: 0.7739
#   ✓ 复制成功: synthesized_speech_70.wav -> synthesized_speech_70.wav
#   使用方法: 1_output
#
# 处理索引 71 (行 72):
#   data_deal_816_output: 0.3322
#   1_output: 0.3594
#   2_output: 0.3378
#   3_output: 0.4085
#   4_output: 0.3564
#   5_output: 0.3886
#   6_output: 0.3717
#   最高分方法: 3_output, 分数: 0.4085
#   ✓ 复制成功: synthesized_speech_71.wav -> synthesized_speech_71.wav
#   使用方法: 3_output
#
# 处理索引 72 (行 73):
#   data_deal_816_output: 0.6614
#   1_output: 0.6515
#   2_output: 0.6430
#   3_output: 0.6303
#   4_output: 0.6343
#   5_output: 0.6730
#   6_output: 0.6288
#   最高分方法: 5_output, 分数: 0.6730
#   ✓ 复制成功: synthesized_speech_72.wav -> synthesized_speech_72.wav
#   使用方法: 5_output
#
# 处理索引 73 (行 74):
#   data_deal_816_output: 0.6864
#   1_output: 0.7118
#   2_output: 0.6981
#   3_output: 0.6966
#   4_output: 0.6817
#   5_output: 0.7208
#   6_output: 0.7143
#   最高分方法: 5_output, 分数: 0.7208
#   ✓ 复制成功: synthesized_speech_73.wav -> synthesized_speech_73.wav
#   使用方法: 5_output
#
# 处理索引 74 (行 75):
#   data_deal_816_output: 0.6055
#   1_output: 0.6350
#   2_output: 0.5695
#   3_output: 0.6416
#   4_output: 0.4972
#   5_output: 0.6101
#   6_output: 0.6231
#   最高分方法: 3_output, 分数: 0.6416
#   ✓ 复制成功: synthesized_speech_74.wav -> synthesized_speech_74.wav
#   使用方法: 3_output
#
# 处理索引 75 (行 76):
#   data_deal_816_output: 0.6806
#   1_output: 0.6796
#   2_output: 0.6885
#   3_output: 0.6955
#   4_output: 0.6901
#   5_output: 0.6946
#   6_output: 0.6066
#   最高分方法: 3_output, 分数: 0.6955
#   ✓ 复制成功: synthesized_speech_75.wav -> synthesized_speech_75.wav
#   使用方法: 3_output
#
# 处理索引 76 (行 77):
#   data_deal_816_output: 0.6342
#   1_output: 0.6410
#   2_output: 0.6549
#   3_output: 0.6592
#   4_output: 0.6475
#   5_output: 0.6437
#   6_output: 0.6691
#   最高分方法: 6_output, 分数: 0.6691
#   ✓ 复制成功: synthesized_speech_76.wav -> synthesized_speech_76.wav
#   使用方法: 6_output
#
# 处理索引 77 (行 78):
#   data_deal_816_output: 0.7276
#   1_output: 0.7332
#   2_output: 0.7254
#   3_output: 0.7234
#   4_output: 0.7144
#   5_output: 0.7052
#   6_output: 0.6979
#   最高分方法: 1_output, 分数: 0.7332
#   ✓ 复制成功: synthesized_speech_77.wav -> synthesized_speech_77.wav
#   使用方法: 1_output
#
# 处理索引 78 (行 79):
#   data_deal_816_output: 0.7354
#   1_output: 无效值
#   2_output: 0.7068
#   3_output: 0.7232
#   4_output: 0.7185
#   5_output: 0.6997
#   6_output: 0.7258
#   最高分方法: data_deal_816_output, 分数: 0.7354
#   ✓ 复制成功: synthesized_speech_78.wav -> synthesized_speech_78.wav
#   使用方法: data_deal_816_output
#
# 处理索引 79 (行 80):
#   data_deal_816_output: 0.8972
#   1_output: 无效值
#   2_output: 无效值
#   3_output: 无效值
#   4_output: 无效值
#   5_output: 0.8847
#   6_output: 0.8987
#   最高分方法: 6_output, 分数: 0.8987
#   ✓ 复制成功: synthesized_speech_79.wav -> synthesized_speech_79.wav
#   使用方法: 6_output
#
# 处理索引 80 (行 81):
#   data_deal_816_output: 0.8001
#   1_output: 无效值
#   2_output: 0.8030
#   3_output: 0.8059
#   4_output: 0.8027
#   5_output: 0.8036
#   6_output: 0.8061
#   最高分方法: 6_output, 分数: 0.8061
#   ✓ 复制成功: synthesized_speech_80.wav -> synthesized_speech_80.wav
#   使用方法: 6_output
#
# 处理索引 81 (行 82):
#   data_deal_816_output: 0.7800
#   1_output: 无效值
#   2_output: 0.7770
#   3_output: 0.7813
#   4_output: 0.7924
#   5_output: 0.7764
#   6_output: 0.7848
#   最高分方法: 4_output, 分数: 0.7924
#   ✓ 复制成功: synthesized_speech_81.wav -> synthesized_speech_81.wav
#   使用方法: 4_output
#
# 处理索引 82 (行 83):
#   data_deal_816_output: 0.8941
#   1_output: 0.8826
#   2_output: 0.8884
#   3_output: 0.8683
#   4_output: 0.8783
#   5_output: 无效值
#   6_output: 0.8865
#   最高分方法: data_deal_816_output, 分数: 0.8941
#   ✓ 复制成功: synthesized_speech_82.wav -> synthesized_speech_82.wav
#   使用方法: data_deal_816_output
#
# 处理索引 83 (行 84):
#   data_deal_816_output: 0.8227
#   1_output: 0.8260
#   2_output: 0.8240
#   3_output: 0.8249
#   4_output: 0.8220
#   5_output: 0.8064
#   6_output: 0.8173
#   最高分方法: 1_output, 分数: 0.8260
#   ✓ 复制成功: synthesized_speech_83.wav -> synthesized_speech_83.wav
#   使用方法: 1_output
#
# 处理索引 84 (行 85):
#   data_deal_816_output: 0.7669
#   1_output: 0.7769
#   2_output: 0.7750
#   3_output: 0.7754
#   4_output: 0.7872
#   5_output: 0.7754
#   6_output: 0.7703
#   最高分方法: 4_output, 分数: 0.7872
#   ✓ 复制成功: synthesized_speech_84.wav -> synthesized_speech_84.wav
#   使用方法: 4_output
#
# 处理索引 85 (行 86):
#   data_deal_816_output: 0.7863
#   1_output: 0.7960
#   2_output: 0.7510
#   3_output: 0.7763
#   4_output: 0.7728
#   5_output: 0.8102
#   6_output: 0.7574
#   最高分方法: 5_output, 分数: 0.8102
#   ✓ 复制成功: synthesized_speech_85.wav -> synthesized_speech_85.wav
#   使用方法: 5_output
#
# 处理索引 86 (行 87):
#   data_deal_816_output: 无效值
#   1_output: 无效值
#   2_output: 无效值
#   3_output: 0.8500
#   4_output: 0.8326
#   5_output: 0.8302
#   6_output: 0.8193
#   最高分方法: 3_output, 分数: 0.8500
#   ✓ 复制成功: synthesized_speech_86.wav -> synthesized_speech_86.wav
#   使用方法: 3_output
#
# 处理索引 87 (行 88):
#   data_deal_816_output: 0.7866
#   1_output: 0.8105
#   2_output: 0.8171
#   3_output: 0.8274
#   4_output: 0.8247
#   5_output: 0.8259
#   6_output: 0.8279
#   最高分方法: 6_output, 分数: 0.8279
#   ✓ 复制成功: synthesized_speech_87.wav -> synthesized_speech_87.wav
#   使用方法: 6_output
#
# 处理索引 88 (行 89):
#   data_deal_816_output: 0.8241
#   1_output: 0.8106
#   2_output: 0.8216
#   3_output: 0.8193
#   4_output: 0.7998
#   5_output: 0.8075
#   6_output: 0.8117
#   最高分方法: data_deal_816_output, 分数: 0.8241
#   ✓ 复制成功: synthesized_speech_88.wav -> synthesized_speech_88.wav
#   使用方法: data_deal_816_output
#
# 处理索引 89 (行 90):
#   data_deal_816_output: 0.5778
#   1_output: 0.5902
#   2_output: 0.5789
#   3_output: 0.5928
#   4_output: 0.5718
#   5_output: 0.5583
#   6_output: 0.5387
#   最高分方法: 3_output, 分数: 0.5928
#   ✓ 复制成功: synthesized_speech_89.wav -> synthesized_speech_89.wav
#   使用方法: 3_output
#
# 处理索引 90 (行 91):
#   data_deal_816_output: 0.7227
#   1_output: 0.7215
#   2_output: 0.7532
#   3_output: 0.7780
#   4_output: 0.7636
#   5_output: 0.7580
#   6_output: 0.7605
#   最高分方法: 3_output, 分数: 0.7780
#   ✓ 复制成功: synthesized_speech_90.wav -> synthesized_speech_90.wav
#   使用方法: 3_output
#
# 处理索引 91 (行 92):
#   data_deal_816_output: 0.7056
#   1_output: 0.6906
#   2_output: 0.6846
#   3_output: 0.6553
#   4_output: 0.6811
#   5_output: 0.6850
#   6_output: 0.6636
#   最高分方法: data_deal_816_output, 分数: 0.7056
#   ✓ 复制成功: synthesized_speech_91.wav -> synthesized_speech_91.wav
#   使用方法: data_deal_816_output
#
# 处理索引 92 (行 93):
#   data_deal_816_output: 0.6719
#   1_output: 0.6871
#   2_output: 0.6698
#   3_output: 0.6513
#   4_output: 0.6677
#   5_output: 0.6630
#   6_output: 0.6710
#   最高分方法: 1_output, 分数: 0.6871
#   ✓ 复制成功: synthesized_speech_92.wav -> synthesized_speech_92.wav
#   使用方法: 1_output
#
# 处理索引 93 (行 94):
#   data_deal_816_output: 0.8289
#   1_output: 0.8316
#   2_output: 0.8230
#   3_output: 0.8263
#   4_output: 0.8449
#   5_output: 0.8325
#   6_output: 0.8224
#   最高分方法: 4_output, 分数: 0.8449
#   ✓ 复制成功: synthesized_speech_93.wav -> synthesized_speech_93.wav
#   使用方法: 4_output
#
# 处理索引 94 (行 95):
#   data_deal_816_output: 0.7624
#   1_output: 0.7617
#   2_output: 0.7616
#   3_output: 0.7593
#   4_output: 0.7539
#   5_output: 0.7579
#   6_output: 0.7640
#   最高分方法: 6_output, 分数: 0.7640
#   ✓ 复制成功: synthesized_speech_94.wav -> synthesized_speech_94.wav
#   使用方法: 6_output
#
# 处理索引 95 (行 96):
#   data_deal_816_output: 0.7708
#   1_output: 0.7567
#   2_output: 0.7246
#   3_output: 0.7555
#   4_output: 0.7727
#   5_output: 0.7675
#   6_output: 0.7713
#   最高分方法: 4_output, 分数: 0.7727
#   ✓ 复制成功: synthesized_speech_95.wav -> synthesized_speech_95.wav
#   使用方法: 4_output
#
# 处理索引 96 (行 97):
#   data_deal_816_output: 0.7684
#   1_output: 0.8064
#   2_output: 0.7926
#   3_output: 0.7980
#   4_output: 0.7919
#   5_output: 0.8200
#   6_output: 0.7984
#   最高分方法: 5_output, 分数: 0.8200
#   ✓ 复制成功: synthesized_speech_96.wav -> synthesized_speech_96.wav
#   使用方法: 5_output
#
# 处理索引 97 (行 98):
#   data_deal_816_output: 0.6525
#   1_output: 0.6742
#   2_output: 0.6598
#   3_output: 0.6590
#   4_output: 0.6559
#   5_output: 0.6589
#   6_output: 0.6479
#   最高分方法: 1_output, 分数: 0.6742
#   ✓ 复制成功: synthesized_speech_97.wav -> synthesized_speech_97.wav
#   使用方法: 1_output
#
# 处理索引 98 (行 99):
#   data_deal_816_output: 0.7482
#   1_output: 0.7315
#   2_output: 0.7782
#   3_output: 0.7934
#   4_output: 0.7570
#   5_output: 0.7556
#   6_output: 0.7507
#   最高分方法: 3_output, 分数: 0.7934
#   ✓ 复制成功: synthesized_speech_98.wav -> synthesized_speech_98.wav
#   使用方法: 3_output
#
# 处理索引 99 (行 100):
#   data_deal_816_output: 0.8353
#   1_output: 0.8336
#   2_output: 0.8442
#   3_output: 0.8358
#   4_output: 0.8381
#   5_output: 0.8451
#   6_output: 0.8401
#   最高分方法: 5_output, 分数: 0.8451
#   ✓ 复制成功: synthesized_speech_99.wav -> synthesized_speech_99.wav
#   使用方法: 5_output
#
# 处理索引 100 (行 101):
#   data_deal_816_output: 0.6734
#   1_output: 0.6688
#   2_output: 0.6684
#   3_output: 0.6774
#   4_output: 0.6754
#   5_output: 0.6928
#   6_output: 0.6753
#   最高分方法: 5_output, 分数: 0.6928
#   ✓ 复制成功: synthesized_speech_100.wav -> synthesized_speech_100.wav
#   使用方法: 5_output
#
# 处理索引 101 (行 102):
#   data_deal_816_output: 0.7395
#   1_output: 0.7412
#   2_output: 0.7445
#   3_output: 0.7562
#   4_output: 0.7566
#   5_output: 0.7612
#   6_output: 0.7619
#   最高分方法: 6_output, 分数: 0.7619
#   ✓ 复制成功: synthesized_speech_101.wav -> synthesized_speech_101.wav
#   使用方法: 6_output
#
# 处理索引 102 (行 103):
#   data_deal_816_output: 0.7728
#   1_output: 0.7708
#   2_output: 0.7445
#   3_output: 0.7609
#   4_output: 0.7526
#   5_output: 0.7320
#   6_output: 0.7635
#   最高分方法: data_deal_816_output, 分数: 0.7728
#   ✓ 复制成功: synthesized_speech_102.wav -> synthesized_speech_102.wav
#   使用方法: data_deal_816_output
#
# 处理索引 103 (行 104):
#   data_deal_816_output: 0.8026
#   1_output: 0.8147
#   2_output: 0.8258
#   3_output: 0.7961
#   4_output: 0.8275
#   5_output: 0.8316
#   6_output: 0.8124
#   最高分方法: 5_output, 分数: 0.8316
#   ✓ 复制成功: synthesized_speech_103.wav -> synthesized_speech_103.wav
#   使用方法: 5_output
#
# 处理索引 104 (行 105):
#   data_deal_816_output: 0.8341
#   1_output: 0.8215
#   2_output: 0.8036
#   3_output: 0.8187
#   4_output: 0.7866
#   5_output: 0.7982
#   6_output: 0.8197
#   最高分方法: data_deal_816_output, 分数: 0.8341
#   ✓ 复制成功: synthesized_speech_104.wav -> synthesized_speech_104.wav
#   使用方法: data_deal_816_output
#
# 处理索引 105 (行 106):
#   data_deal_816_output: 无效值
#   1_output: 无效值
#   2_output: 无效值
#   3_output: 0.9165
#   4_output: 0.8987
#   5_output: 0.9013
#   6_output: 0.8886
#   最高分方法: 3_output, 分数: 0.9165
#   ✓ 复制成功: synthesized_speech_105.wav -> synthesized_speech_105.wav
#   使用方法: 3_output
#
# 处理索引 106 (行 107):
#   data_deal_816_output: 0.7660
#   1_output: 0.7711
#   2_output: 0.7655
#   3_output: 0.7780
#   4_output: 0.7663
#   5_output: 0.7602
#   6_output: 0.7468
#   最高分方法: 3_output, 分数: 0.7780
#   ✓ 复制成功: synthesized_speech_106.wav -> synthesized_speech_106.wav
#   使用方法: 3_output
#
# 处理索引 107 (行 108):
#   data_deal_816_output: 0.8308
#   1_output: 0.8442
#   2_output: 0.8318
#   3_output: 0.8385
#   4_output: 0.8464
#   5_output: 0.8297
#   6_output: 0.8309
#   最高分方法: 4_output, 分数: 0.8464
#   ✓ 复制成功: synthesized_speech_107.wav -> synthesized_speech_107.wav
#   使用方法: 4_output
#
# 处理索引 108 (行 109):
#   data_deal_816_output: 0.8573
#   1_output: 0.8502
#   2_output: 0.8532
#   3_output: 0.8585
#   4_output: 0.8544
#   5_output: 0.8538
#   6_output: 0.8382
#   最高分方法: 3_output, 分数: 0.8585
#   ✓ 复制成功: synthesized_speech_108.wav -> synthesized_speech_108.wav
#   使用方法: 3_output
#
# 处理索引 109 (行 110):
#   data_deal_816_output: 0.7446
#   1_output: 0.7218
#   2_output: 0.7107
#   3_output: 0.7439
#   4_output: 0.7411
#   5_output: 0.7207
#   6_output: 0.7257
#   最高分方法: data_deal_816_output, 分数: 0.7446
#   ✓ 复制成功: synthesized_speech_109.wav -> synthesized_speech_109.wav
#   使用方法: data_deal_816_output
#
# 处理索引 110 (行 111):
#   data_deal_816_output: 0.7175
#   1_output: 0.7333
#   2_output: 0.6971
#   3_output: 0.7069
#   4_output: 0.7057
#   5_output: 0.7056
#   6_output: 0.7006
#   最高分方法: 1_output, 分数: 0.7333
#   ✓ 复制成功: synthesized_speech_110.wav -> synthesized_speech_110.wav
#   使用方法: 1_output
#
# 处理索引 111 (行 112):
#   data_deal_816_output: 0.8440
#   1_output: 0.8213
#   2_output: 0.8439
#   3_output: 0.8220
#   4_output: 0.8252
#   5_output: 0.8312
#   6_output: 0.8189
#   最高分方法: data_deal_816_output, 分数: 0.8440
#   ✓ 复制成功: synthesized_speech_111.wav -> synthesized_speech_111.wav
#   使用方法: data_deal_816_output
#
# 处理索引 112 (行 113):
#   data_deal_816_output: 0.5381
#   1_output: 0.5183
#   2_output: 0.5461
#   3_output: 0.4798
#   4_output: 0.5289
#   5_output: 0.4981
#   6_output: 0.5391
#   最高分方法: 2_output, 分数: 0.5461
#   ✓ 复制成功: synthesized_speech_112.wav -> synthesized_speech_112.wav
#   使用方法: 2_output
#
# 处理索引 113 (行 114):
#   data_deal_816_output: 0.6234
#   1_output: 0.6552
#   2_output: 0.6456
#   3_output: 0.6584
#   4_output: 0.6768
#   5_output: 0.6372
#   6_output: 0.6632
#   最高分方法: 4_output, 分数: 0.6768
#   ✓ 复制成功: synthesized_speech_113.wav -> synthesized_speech_113.wav
#   使用方法: 4_output
#
# 处理索引 114 (行 115):
#   data_deal_816_output: 0.5293
#   1_output: 0.5617
#   2_output: 0.5745
#   3_output: 0.5407
#   4_output: 0.5657
#   5_output: 0.6056
#   6_output: 0.5801
#   最高分方法: 5_output, 分数: 0.6056
#   ✓ 复制成功: synthesized_speech_114.wav -> synthesized_speech_114.wav
#   使用方法: 5_output
#
# 处理索引 115 (行 116):
#   data_deal_816_output: 0.6597
#   1_output: 0.6492
#   2_output: 0.5629
#   3_output: 0.6195
#   4_output: 0.5902
#   5_output: 0.5800
#   6_output: 0.6667
#   最高分方法: 6_output, 分数: 0.6667
#   ✓ 复制成功: synthesized_speech_115.wav -> synthesized_speech_115.wav
#   使用方法: 6_output
#
# 处理索引 116 (行 117):
#   data_deal_816_output: 0.6036
#   1_output: 0.6136
#   2_output: 0.6501
#   3_output: 0.6560
#   4_output: 0.5133
#   5_output: 0.6853
#   6_output: 0.6659
#   最高分方法: 5_output, 分数: 0.6853
#   ✓ 复制成功: synthesized_speech_116.wav -> synthesized_speech_116.wav
#   使用方法: 5_output
#
# 处理索引 117 (行 118):
#   data_deal_816_output: 0.8833
#   1_output: 无效值
#   2_output: 无效值
#   3_output: 无效值
#   4_output: 无效值
#   5_output: 无效值
#   6_output: 0.8875
#   最高分方法: 6_output, 分数: 0.8875
#   ✓ 复制成功: synthesized_speech_117.wav -> synthesized_speech_117.wav
#   使用方法: 6_output
#
# 处理索引 118 (行 119):
#   data_deal_816_output: 0.7322
#   1_output: 0.7342
#   2_output: 0.7100
#   3_output: 0.7369
#   4_output: 0.6543
#   5_output: 0.7338
#   6_output: 0.7273
#   最高分方法: 3_output, 分数: 0.7369
#   ✓ 复制成功: synthesized_speech_118.wav -> synthesized_speech_118.wav
#   使用方法: 3_output
#
# 处理索引 119 (行 120):
#   data_deal_816_output: 0.7665
#   1_output: 0.7569
#   2_output: 0.7721
#   3_output: 0.7676
#   4_output: 0.7635
#   5_output: 0.7686
#   6_output: 0.7592
#   最高分方法: 2_output, 分数: 0.7721
#   ✓ 复制成功: synthesized_speech_119.wav -> synthesized_speech_119.wav
#   使用方法: 2_output
#
# 处理索引 120 (行 121):
#   data_deal_816_output: 0.7553
#   1_output: 0.7892
#   2_output: 0.8074
#   3_output: 0.7963
#   4_output: 0.7779
#   5_output: 0.7913
#   6_output: 0.7885
#   最高分方法: 2_output, 分数: 0.8074
#   ✓ 复制成功: synthesized_speech_120.wav -> synthesized_speech_120.wav
#   使用方法: 2_output
#
# 处理索引 121 (行 122):
#   data_deal_816_output: 0.8476
#   1_output: 0.8458
#   2_output: 0.8656
#   3_output: 0.8430
#   4_output: 0.8603
#   5_output: 0.8529
#   6_output: 0.8639
#   最高分方法: 2_output, 分数: 0.8656
#   ✓ 复制成功: synthesized_speech_121.wav -> synthesized_speech_121.wav
#   使用方法: 2_output
#
# 处理索引 122 (行 123):
#   data_deal_816_output: 0.5789
#   1_output: 0.4957
#   2_output: 0.5304
#   3_output: 0.5242
#   4_output: 0.4654
#   5_output: 0.5214
#   6_output: 0.5146
#   最高分方法: data_deal_816_output, 分数: 0.5789
#   ✓ 复制成功: synthesized_speech_122.wav -> synthesized_speech_122.wav
#   使用方法: data_deal_816_output
#
# 处理索引 123 (行 124):
#   data_deal_816_output: 0.5386
#   1_output: 0.5260
#   2_output: 0.5965
#   3_output: 0.5350
#   4_output: 0.5334
#   5_output: 0.5557
#   6_output: 0.5441
#   最高分方法: 2_output, 分数: 0.5965
#   ✓ 复制成功: synthesized_speech_123.wav -> synthesized_speech_123.wav
#   使用方法: 2_output
#
# 处理索引 124 (行 125):
#   data_deal_816_output: 0.7756
#   1_output: 0.7679
#   2_output: 0.7540
#   3_output: 0.7653
#   4_output: 0.7870
#   5_output: 0.7673
#   6_output: 0.7636
#   最高分方法: 4_output, 分数: 0.7870
#   ✓ 复制成功: synthesized_speech_124.wav -> synthesized_speech_124.wav
#   使用方法: 4_output
#
# 处理索引 125 (行 126):
#   data_deal_816_output: 0.5240
#   1_output: 0.5767
#   2_output: 0.5610
#   3_output: 0.5588
#   4_output: 0.6130
#   5_output: 0.6136
#   6_output: 0.6221
#   最高分方法: 6_output, 分数: 0.6221
#   ✓ 复制成功: synthesized_speech_125.wav -> synthesized_speech_125.wav
#   使用方法: 6_output
#
# 处理索引 126 (行 127):
#   data_deal_816_output: 0.6998
#   1_output: 0.7264
#   2_output: 0.6561
#   3_output: 0.6978
#   4_output: 0.6649
#   5_output: 0.6691
#   6_output: 0.6756
#   最高分方法: 1_output, 分数: 0.7264
#   ✓ 复制成功: synthesized_speech_126.wav -> synthesized_speech_126.wav
#   使用方法: 1_output
#
# 处理索引 127 (行 128):
#   data_deal_816_output: 0.6010
#   1_output: 0.5830
#   2_output: 0.5902
#   3_output: 0.5797
#   4_output: 0.5838
#   5_output: 0.6062
#   6_output: 0.5784
#   最高分方法: 5_output, 分数: 0.6062
#   ✓ 复制成功: synthesized_speech_127.wav -> synthesized_speech_127.wav
#   使用方法: 5_output
#
# 处理索引 128 (行 129):
#   data_deal_816_output: 0.8721
#   1_output: 无效值
#   2_output: 无效值
#   3_output: 无效值
#   4_output: 无效值
#   5_output: 0.8382
#   6_output: 0.8697
#   最高分方法: data_deal_816_output, 分数: 0.8721
#   ✓ 复制成功: synthesized_speech_128.wav -> synthesized_speech_128.wav
#   使用方法: data_deal_816_output
#
# 处理索引 129 (行 130):
#   data_deal_816_output: 0.5307
#   1_output: 0.5361
#   2_output: 0.5195
#   3_output: 0.5711
#   4_output: 0.5216
#   5_output: 0.5410
#   6_output: 0.5284
#   最高分方法: 3_output, 分数: 0.5711
#   ✓ 复制成功: synthesized_speech_129.wav -> synthesized_speech_129.wav
#   使用方法: 3_output
#
# 处理索引 130 (行 131):
#   data_deal_816_output: 0.6626
#   1_output: 0.6492
#   2_output: 0.6130
#   3_output: 0.5669
#   4_output: 0.5788
#   5_output: 0.6026
#   6_output: 0.6212
#   最高分方法: data_deal_816_output, 分数: 0.6626
#   ✓ 复制成功: synthesized_speech_130.wav -> synthesized_speech_130.wav
#   使用方法: data_deal_816_output
#
# 处理索引 131 (行 132):
#   data_deal_816_output: 0.7411
#   1_output: 0.7443
#   2_output: 0.7469
#   3_output: 0.7414
#   4_output: 0.7523
#   5_output: 0.7518
#   6_output: 0.7475
#   最高分方法: 4_output, 分数: 0.7523
#   ✓ 复制成功: synthesized_speech_131.wav -> synthesized_speech_131.wav
#   使用方法: 4_output
#
# 处理索引 132 (行 133):
#   data_deal_816_output: 0.7698
#   1_output: 0.7614
#   2_output: 0.7540
#   3_output: 0.7681
#   4_output: 0.7632
#   5_output: 0.7734
#   6_output: 0.7481
#   最高分方法: 5_output, 分数: 0.7734
#   ✓ 复制成功: synthesized_speech_132.wav -> synthesized_speech_132.wav
#   使用方法: 5_output
#
# 处理索引 133 (行 134):
#   data_deal_816_output: 0.6862
#   1_output: 0.6780
#   2_output: 0.6806
#   3_output: 0.7141
#   4_output: 0.7011
#   5_output: 0.6966
#   6_output: 0.7115
#   最高分方法: 3_output, 分数: 0.7141
#   ✓ 复制成功: synthesized_speech_133.wav -> synthesized_speech_133.wav
#   使用方法: 3_output
#
# 处理索引 134 (行 135):
#   data_deal_816_output: 0.7580
#   1_output: 0.7413
#   2_output: 0.7438
#   3_output: 0.7430
#   4_output: 0.7390
#   5_output: 0.7432
#   6_output: 0.7506
#   最高分方法: data_deal_816_output, 分数: 0.7580
#   ✓ 复制成功: synthesized_speech_134.wav -> synthesized_speech_134.wav
#   使用方法: data_deal_816_output
#
# 处理索引 135 (行 136):
#   data_deal_816_output: 0.7396
#   1_output: 0.7804
#   2_output: 0.8092
#   3_output: 0.7871
#   4_output: 0.8093
#   5_output: 0.7903
#   6_output: 0.7944
#   最高分方法: 4_output, 分数: 0.8093
#   ✓ 复制成功: synthesized_speech_135.wav -> synthesized_speech_135.wav
#   使用方法: 4_output
#
# 处理索引 136 (行 137):
#   data_deal_816_output: 0.7433
#   1_output: 0.7620
#   2_output: 0.7342
#   3_output: 0.7546
#   4_output: 0.7360
#   5_output: 0.7594
#   6_output: 0.7595
#   最高分方法: 1_output, 分数: 0.7620
#   ✓ 复制成功: synthesized_speech_136.wav -> synthesized_speech_136.wav
#   使用方法: 1_output
#
# 处理索引 137 (行 138):
#   data_deal_816_output: 0.7635
#   1_output: 0.7755
#   2_output: 0.7684
#   3_output: 0.7609
#   4_output: 0.7712
#   5_output: 0.7714
#   6_output: 0.7731
#   最高分方法: 1_output, 分数: 0.7755
#   ✓ 复制成功: synthesized_speech_137.wav -> synthesized_speech_137.wav
#   使用方法: 1_output
#
# 处理索引 138 (行 139):
#   data_deal_816_output: 0.6942
#   1_output: 0.7200
#   2_output: 0.6716
#   3_output: 0.6997
#   4_output: 0.6579
#   5_output: 0.7029
#   6_output: 0.6854
#   最高分方法: 1_output, 分数: 0.7200
#   ✓ 复制成功: synthesized_speech_138.wav -> synthesized_speech_138.wav
#   使用方法: 1_output
#
# 处理索引 139 (行 140):
#   data_deal_816_output: 0.5751
#   1_output: 0.5871
#   2_output: 0.5417
#   3_output: 0.5564
#   4_output: 0.5563
#   5_output: 0.5558
#   6_output: 0.5669
#   最高分方法: 1_output, 分数: 0.5871
#   ✓ 复制成功: synthesized_speech_139.wav -> synthesized_speech_139.wav
#   使用方法: 1_output
#
# 处理索引 140 (行 141):
#   data_deal_816_output: 0.7087
#   1_output: 0.6830
#   2_output: 0.6848
#   3_output: 0.6963
#   4_output: 0.6830
#   5_output: 0.6651
#   6_output: 0.6892
#   最高分方法: data_deal_816_output, 分数: 0.7087
#   ✓ 复制成功: synthesized_speech_140.wav -> synthesized_speech_140.wav
#   使用方法: data_deal_816_output
#
# 处理索引 141 (行 142):
#   data_deal_816_output: 0.5741
#   1_output: 0.6029
#   2_output: 0.5847
#   3_output: 0.5939
#   4_output: 0.5948
#   5_output: 0.5826
#   6_output: 0.5892
#   最高分方法: 1_output, 分数: 0.6029
#   ✓ 复制成功: synthesized_speech_141.wav -> synthesized_speech_141.wav
#   使用方法: 1_output
#
# 处理索引 142 (行 143):
#   data_deal_816_output: 0.8085
#   1_output: 0.8054
#   2_output: 0.7889
#   3_output: 0.8149
#   4_output: 0.8024
#   5_output: 0.8086
#   6_output: 0.8276
#   最高分方法: 6_output, 分数: 0.8276
#   ✓ 复制成功: synthesized_speech_142.wav -> synthesized_speech_142.wav
#   使用方法: 6_output
#
# 处理索引 143 (行 144):
#   data_deal_816_output: 0.6957
#   1_output: 0.7284
#   2_output: 0.6979
#   3_output: 0.7309
#   4_output: 0.7114
#   5_output: 0.6898
#   6_output: 0.6998
#   最高分方法: 3_output, 分数: 0.7309
#   ✓ 复制成功: synthesized_speech_143.wav -> synthesized_speech_143.wav
#   使用方法: 3_output
#
# 处理索引 144 (行 145):
#   data_deal_816_output: 0.5713
#   1_output: 0.5557
#   2_output: 0.5891
#   3_output: 0.6130
#   4_output: 0.5724
#   5_output: 0.5996
#   6_output: 0.5947
#   最高分方法: 3_output, 分数: 0.6130
#   ✓ 复制成功: synthesized_speech_144.wav -> synthesized_speech_144.wav
#   使用方法: 3_output
#
# 处理索引 145 (行 146):
#   data_deal_816_output: 0.8039
#   1_output: 0.8179
#   2_output: 0.7928
#   3_output: 0.7866
#   4_output: 0.8112
#   5_output: 0.8077
#   6_output: 0.8072
#   最高分方法: 1_output, 分数: 0.8179
#   ✓ 复制成功: synthesized_speech_145.wav -> synthesized_speech_145.wav
#   使用方法: 1_output
#
# 处理索引 146 (行 147):
#   data_deal_816_output: 0.7544
#   1_output: 0.7500
#   2_output: 0.7608
#   3_output: 0.7234
#   4_output: 0.7473
#   5_output: 0.7741
#   6_output: 0.7633
#   最高分方法: 5_output, 分数: 0.7741
#   ✓ 复制成功: synthesized_speech_146.wav -> synthesized_speech_146.wav
#   使用方法: 5_output
#
# 处理索引 147 (行 148):
#   data_deal_816_output: 0.8185
#   1_output: 0.7999
#   2_output: 0.8103
#   3_output: 0.8128
#   4_output: 0.8149
#   5_output: 0.7997
#   6_output: 0.8080
#   最高分方法: data_deal_816_output, 分数: 0.8185
#   ✓ 复制成功: synthesized_speech_147.wav -> synthesized_speech_147.wav
#   使用方法: data_deal_816_output
#
# 处理索引 148 (行 149):
#   data_deal_816_output: 0.7378
#   1_output: 0.7443
#   2_output: 0.6965
#   3_output: 0.7197
#   4_output: 0.6936
#   5_output: 0.7107
#   6_output: 0.7316
#   最高分方法: 1_output, 分数: 0.7443
#   ✓ 复制成功: synthesized_speech_148.wav -> synthesized_speech_148.wav
#   使用方法: 1_output
#
# 处理索引 149 (行 150):
#   data_deal_816_output: 无效值
#   1_output: 0.7454
#   2_output: 0.7636
#   3_output: 0.7525
#   4_output: 0.7494
#   5_output: 0.7571
#   6_output: 0.7692
#   最高分方法: 6_output, 分数: 0.7692
#   ✓ 复制成功: synthesized_speech_149.wav -> synthesized_speech_149.wav
#   使用方法: 6_output
#
# 处理索引 150 (行 151):
#   data_deal_816_output: 0.7260
#   1_output: 0.7530
#   2_output: 0.7577
#   3_output: 0.7594
#   4_output: 0.7471
#   5_output: 0.7589
#   6_output: 0.7625
#   最高分方法: 6_output, 分数: 0.7625
#   ✓ 复制成功: synthesized_speech_150.wav -> synthesized_speech_150.wav
#   使用方法: 6_output
#
# 处理索引 151 (行 152):
#   data_deal_816_output: 0.6715
#   1_output: 0.7228
#   2_output: 0.7120
#   3_output: 0.7188
#   4_output: 0.7000
#   5_output: 0.7247
#   6_output: 0.7459
#   最高分方法: 6_output, 分数: 0.7459
#   ✓ 复制成功: synthesized_speech_151.wav -> synthesized_speech_151.wav
#   使用方法: 6_output
#
# 处理索引 152 (行 153):
#   data_deal_816_output: 0.3691
#   1_output: 0.3183
#   2_output: 0.3761
#   3_output: 0.4038
#   4_output: 0.4199
#   5_output: 0.3841
#   6_output: 0.4047
#   最高分方法: 4_output, 分数: 0.4199
#   ✓ 复制成功: synthesized_speech_152.wav -> synthesized_speech_152.wav
#   使用方法: 4_output
#
# 处理索引 153 (行 154):
#   data_deal_816_output: 0.7595
#   1_output: 0.7759
#   2_output: 0.7669
#   3_output: 0.7763
#   4_output: 0.7744
#   5_output: 0.7879
#   6_output: 0.7766
#   最高分方法: 5_output, 分数: 0.7879
#   ✓ 复制成功: synthesized_speech_153.wav -> synthesized_speech_153.wav
#   使用方法: 5_output
#
# 处理索引 154 (行 155):
#   data_deal_816_output: 0.8645
#   1_output: 0.8428
#   2_output: 0.8605
#   3_output: 0.8549
#   4_output: 0.8450
#   5_output: 0.8444
#   6_output: 0.8554
#   最高分方法: data_deal_816_output, 分数: 0.8645
#   ✓ 复制成功: synthesized_speech_154.wav -> synthesized_speech_154.wav
#   使用方法: data_deal_816_output
#
# 处理索引 155 (行 156):
#   data_deal_816_output: 0.4219
#   1_output: 0.4093
#   2_output: 0.4058
#   3_output: 0.3968
#   4_output: 0.4240
#   5_output: 0.4181
#   6_output: 0.3954
#   最高分方法: 4_output, 分数: 0.4240
#   ✓ 复制成功: synthesized_speech_155.wav -> synthesized_speech_155.wav
#   使用方法: 4_output
#
# 处理索引 156 (行 157):
#   data_deal_816_output: 0.6258
#   1_output: 0.6292
#   2_output: 0.6159
#   3_output: 0.6149
#   4_output: 0.6132
#   5_output: 0.6305
#   6_output: 0.6411
#   最高分方法: 6_output, 分数: 0.6411
#   ✓ 复制成功: synthesized_speech_156.wav -> synthesized_speech_156.wav
#   使用方法: 6_output
#
# 处理索引 157 (行 158):
#   data_deal_816_output: 0.7622
#   1_output: 0.7605
#   2_output: 0.7540
#   3_output: 0.7693
#   4_output: 0.7502
#   5_output: 0.7510
#   6_output: 0.7588
#   最高分方法: 3_output, 分数: 0.7693
#   ✓ 复制成功: synthesized_speech_157.wav -> synthesized_speech_157.wav
#   使用方法: 3_output
#
# 处理索引 158 (行 159):
#   data_deal_816_output: 0.7553
#   1_output: 0.8031
#   2_output: 0.7868
#   3_output: 0.7881
#   4_output: 0.7754
#   5_output: 0.8161
#   6_output: 0.8042
#   最高分方法: 5_output, 分数: 0.8161
#   ✓ 复制成功: synthesized_speech_158.wav -> synthesized_speech_158.wav
#   使用方法: 5_output
#
# 处理索引 159 (行 160):
#   data_deal_816_output: 0.7342
#   1_output: 0.7278
#   2_output: 0.7224
#   3_output: 0.7423
#   4_output: 0.7441
#   5_output: 0.7459
#   6_output: 0.7304
#   最高分方法: 5_output, 分数: 0.7459
#   ✓ 复制成功: synthesized_speech_159.wav -> synthesized_speech_159.wav
#   使用方法: 5_output
#
# 处理索引 160 (行 161):
#   data_deal_816_output: 0.7777
#   1_output: 0.7725
#   2_output: 0.7752
#   3_output: 0.7576
#   4_output: 0.7699
#   5_output: 0.7664
#   6_output: 0.7749
#   最高分方法: data_deal_816_output, 分数: 0.7777
#   ✓ 复制成功: synthesized_speech_160.wav -> synthesized_speech_160.wav
#   使用方法: data_deal_816_output
#
# 处理索引 161 (行 162):
#   data_deal_816_output: 0.5929
#   1_output: 0.5768
#   2_output: 0.5671
#   3_output: 0.5310
#   4_output: 0.5507
#   5_output: 0.5698
#   6_output: 0.5775
#   最高分方法: data_deal_816_output, 分数: 0.5929
#   ✓ 复制成功: synthesized_speech_161.wav -> synthesized_speech_161.wav
#   使用方法: data_deal_816_output
#
# 处理索引 162 (行 163):
#   data_deal_816_output: 0.8302
#   1_output: 0.8239
#   2_output: 0.8310
#   3_output: 0.8261
#   4_output: 0.8145
#   5_output: 0.8206
#   6_output: 0.8305
#   最高分方法: 2_output, 分数: 0.8310
#   ✓ 复制成功: synthesized_speech_162.wav -> synthesized_speech_162.wav
#   使用方法: 2_output
#
# 处理索引 163 (行 164):
#   data_deal_816_output: 0.8574
#   1_output: 0.8202
#   2_output: 0.8603
#   3_output: 0.8258
#   4_output: 0.8319
#   5_output: 0.8406
#   6_output: 0.8350
#   最高分方法: 2_output, 分数: 0.8603
#   ✓ 复制成功: synthesized_speech_163.wav -> synthesized_speech_163.wav
#   使用方法: 2_output
#
# 处理索引 164 (行 165):
#   data_deal_816_output: 0.6812
#   1_output: 0.7022
#   2_output: 0.6897
#   3_output: 0.7016
#   4_output: 0.7051
#   5_output: 0.7005
#   6_output: 0.6969
#   最高分方法: 4_output, 分数: 0.7051
#   ✓ 复制成功: synthesized_speech_164.wav -> synthesized_speech_164.wav
#   使用方法: 4_output
#
# 处理索引 165 (行 166):
#   data_deal_816_output: 0.6782
#   1_output: 0.6913
#   2_output: 0.6808
#   3_output: 0.6909
#   4_output: 0.6695
#   5_output: 0.6844
#   6_output: 0.6752
#   最高分方法: 1_output, 分数: 0.6913
#   ✓ 复制成功: synthesized_speech_165.wav -> synthesized_speech_165.wav
#   使用方法: 1_output
#
# 处理索引 166 (行 167):
#   data_deal_816_output: 0.7482
#   1_output: 0.7442
#   2_output: 0.6901
#   3_output: 0.7161
#   4_output: 0.7486
#   5_output: 0.7074
#   6_output: 0.7181
#   最高分方法: 4_output, 分数: 0.7486
#   ✓ 复制成功: synthesized_speech_166.wav -> synthesized_speech_166.wav
#   使用方法: 4_output
#
# 处理索引 167 (行 168):
#   data_deal_816_output: 0.7976
#   1_output: 0.8002
#   2_output: 0.8148
#   3_output: 0.8281
#   4_output: 0.8106
#   5_output: 0.8031
#   6_output: 0.8141
#   最高分方法: 3_output, 分数: 0.8281
#   ✓ 复制成功: synthesized_speech_167.wav -> synthesized_speech_167.wav
#   使用方法: 3_output
#
# 处理索引 168 (行 169):
#   data_deal_816_output: 0.3639
#   1_output: 0.3311
#   2_output: 0.4261
#   3_output: 0.3495
#   4_output: 0.3758
#   5_output: 0.3852
#   6_output: 0.3977
#   最高分方法: 2_output, 分数: 0.4261
#   ✓ 复制成功: synthesized_speech_168.wav -> synthesized_speech_168.wav
#   使用方法: 2_output
#
# 处理索引 169 (行 170):
#   data_deal_816_output: 0.8019
#   1_output: 0.7833
#   2_output: 0.7965
#   3_output: 0.7699
#   4_output: 0.8027
#   5_output: 0.7932
#   6_output: 0.7908
#   最高分方法: 4_output, 分数: 0.8027
#   ✓ 复制成功: synthesized_speech_169.wav -> synthesized_speech_169.wav
#   使用方法: 4_output
#
# 处理索引 170 (行 171):
#   data_deal_816_output: 0.7416
#   1_output: 0.7353
#   2_output: 0.7369
#   3_output: 0.7480
#   4_output: 0.7471
#   5_output: 0.7354
#   6_output: 0.7236
#   最高分方法: 3_output, 分数: 0.7480
#   ✓ 复制成功: synthesized_speech_170.wav -> synthesized_speech_170.wav
#   使用方法: 3_output
#
# 处理索引 171 (行 172):
#   data_deal_816_output: 0.8173
#   1_output: 0.7894
#   2_output: 0.7990
#   3_output: 0.8005
#   4_output: 0.7989
#   5_output: 0.7922
#   6_output: 0.8000
#   最高分方法: data_deal_816_output, 分数: 0.8173
#   ✓ 复制成功: synthesized_speech_171.wav -> synthesized_speech_171.wav
#   使用方法: data_deal_816_output
#
# 处理索引 172 (行 173):
#   data_deal_816_output: 0.6797
#   1_output: 0.7124
#   2_output: 0.6977
#   3_output: 0.6945
#   4_output: 0.6891
#   5_output: 0.7123
#   6_output: 0.7196
#   最高分方法: 6_output, 分数: 0.7196
#   ✓ 复制成功: synthesized_speech_172.wav -> synthesized_speech_172.wav
#   使用方法: 6_output
#
# 处理索引 173 (行 174):
#   data_deal_816_output: 0.6786
#   1_output: 0.6245
#   2_output: 0.6724
#   3_output: 0.6592
#   4_output: 0.6615
#   5_output: 0.6578
#   6_output: 0.6828
#   最高分方法: 6_output, 分数: 0.6828
#   ✓ 复制成功: synthesized_speech_173.wav -> synthesized_speech_173.wav
#   使用方法: 6_output
#
# 处理索引 174 (行 175):
#   data_deal_816_output: 0.6301
#   1_output: 0.6285
#   2_output: 0.6437
#   3_output: 0.6641
#   4_output: 0.6434
#   5_output: 0.6259
#   6_output: 0.6551
#   最高分方法: 3_output, 分数: 0.6641
#   ✓ 复制成功: synthesized_speech_174.wav -> synthesized_speech_174.wav
#   使用方法: 3_output
#
# 处理索引 175 (行 176):
#   data_deal_816_output: 0.7390
#   1_output: 0.6860
#   2_output: 0.7483
#   3_output: 0.7030
#   4_output: 0.6734
#   5_output: 0.7141
#   6_output: 0.7128
#   最高分方法: 2_output, 分数: 0.7483
#   ✓ 复制成功: synthesized_speech_175.wav -> synthesized_speech_175.wav
#   使用方法: 2_output
#
# 处理索引 176 (行 177):
#   data_deal_816_output: 0.8176
#   1_output: 0.8305
#   2_output: 0.8156
#   3_output: 0.8496
#   4_output: 0.8212
#   5_output: 0.8347
#   6_output: 0.8246
#   最高分方法: 3_output, 分数: 0.8496
#   ✓ 复制成功: synthesized_speech_176.wav -> synthesized_speech_176.wav
#   使用方法: 3_output
#
# 处理索引 177 (行 178):
#   data_deal_816_output: 0.8186
#   1_output: 无效值
#   2_output: 无效值
#   3_output: 0.8473
#   4_output: 0.8289
#   5_output: 0.8389
#   6_output: 0.8534
#   最高分方法: 6_output, 分数: 0.8534
#   ✓ 复制成功: synthesized_speech_177.wav -> synthesized_speech_177.wav
#   使用方法: 6_output
#
# 处理索引 178 (行 179):
#   data_deal_816_output: 0.6907
#   1_output: 0.6837
#   2_output: 0.7021
#   3_output: 0.6370
#   4_output: 0.6891
#   5_output: 0.6890
#   6_output: 0.6970
#   最高分方法: 2_output, 分数: 0.7021
#   ✓ 复制成功: synthesized_speech_178.wav -> synthesized_speech_178.wav
#   使用方法: 2_output
#
# 处理索引 179 (行 180):
#   data_deal_816_output: 0.7183
#   1_output: 0.7350
#   2_output: 0.7349
#   3_output: 0.7361
#   4_output: 0.7147
#   5_output: 0.7336
#   6_output: 0.7403
#   最高分方法: 6_output, 分数: 0.7403
#   ✓ 复制成功: synthesized_speech_179.wav -> synthesized_speech_179.wav
#   使用方法: 6_output
#
# 处理索引 180 (行 181):
#   data_deal_816_output: 0.8555
#   1_output: 0.8745
#   2_output: 0.8535
#   3_output: 0.8408
#   4_output: 0.8783
#   5_output: 0.8681
#   6_output: 0.8754
#   最高分方法: 4_output, 分数: 0.8783
#   ✓ 复制成功: synthesized_speech_180.wav -> synthesized_speech_180.wav
#   使用方法: 4_output
#
# 处理索引 181 (行 182):
#   data_deal_816_output: 0.7873
#   1_output: 0.7579
#   2_output: 0.7817
#   3_output: 0.7891
#   4_output: 0.7791
#   5_output: 0.7826
#   6_output: 0.7937
#   最高分方法: 6_output, 分数: 0.7937
#   ✓ 复制成功: synthesized_speech_181.wav -> synthesized_speech_181.wav
#   使用方法: 6_output
#
# 处理索引 182 (行 183):
#   data_deal_816_output: 0.7691
#   1_output: 0.8002
#   2_output: 0.8000
#   3_output: 0.7859
#   4_output: 0.7924
#   5_output: 0.8105
#   6_output: 0.8195
#   最高分方法: 6_output, 分数: 0.8195
#   ✓ 复制成功: synthesized_speech_182.wav -> synthesized_speech_182.wav
#   使用方法: 6_output
#
# 处理索引 183 (行 184):
#   data_deal_816_output: 0.7665
#   1_output: 0.7705
#   2_output: 0.7804
#   3_output: 0.7750
#   4_output: 0.7748
#   5_output: 0.7594
#   6_output: 0.7738
#   最高分方法: 2_output, 分数: 0.7804
#   ✓ 复制成功: synthesized_speech_183.wav -> synthesized_speech_183.wav
#   使用方法: 2_output
#
# 处理索引 184 (行 185):
#   data_deal_816_output: 0.7067
#   1_output: 0.6924
#   2_output: 0.7072
#   3_output: 0.6812
#   4_output: 0.6975
#   5_output: 0.6891
#   6_output: 0.6947
#   最高分方法: 2_output, 分数: 0.7072
#   ✓ 复制成功: synthesized_speech_184.wav -> synthesized_speech_184.wav
#   使用方法: 2_output
#
# 处理索引 185 (行 186):
#   data_deal_816_output: 0.6804
#   1_output: 0.6967
#   2_output: 0.6961
#   3_output: 0.6799
#   4_output: 0.6602
#   5_output: 0.7025
#   6_output: 0.7018
#   最高分方法: 5_output, 分数: 0.7025
#   ✓ 复制成功: synthesized_speech_185.wav -> synthesized_speech_185.wav
#   使用方法: 5_output
#
# 处理索引 186 (行 187):
#   data_deal_816_output: 0.6073
#   1_output: 0.6249
#   2_output: 0.5975
#   3_output: 0.5626
#   4_output: 0.6135
#   5_output: 0.6156
#   6_output: 0.6263
#   最高分方法: 6_output, 分数: 0.6263
#   ✓ 复制成功: synthesized_speech_186.wav -> synthesized_speech_186.wav
#   使用方法: 6_output
#
# 处理索引 187 (行 188):
#   data_deal_816_output: 0.8070
#   1_output: 0.8128
#   2_output: 0.8299
#   3_output: 0.8049
#   4_output: 0.8075
#   5_output: 0.8151
#   6_output: 0.8105
#   最高分方法: 2_output, 分数: 0.8299
#   ✓ 复制成功: synthesized_speech_187.wav -> synthesized_speech_187.wav
#   使用方法: 2_output
#
# 处理索引 188 (行 189):
#   data_deal_816_output: 0.8411
#   1_output: 0.8298
#   2_output: 0.8311
#   3_output: 0.8246
#   4_output: 0.8269
#   5_output: 0.8375
#   6_output: 0.8249
#   最高分方法: data_deal_816_output, 分数: 0.8411
#   ✓ 复制成功: synthesized_speech_188.wav -> synthesized_speech_188.wav
#   使用方法: data_deal_816_output
#
# 处理索引 189 (行 190):
#   data_deal_816_output: 0.8021
#   1_output: 0.7943
#   2_output: 0.7850
#   3_output: 0.7915
#   4_output: 0.7760
#   5_output: 0.7835
#   6_output: 0.8019
#   最高分方法: data_deal_816_output, 分数: 0.8021
#   ✓ 复制成功: synthesized_speech_189.wav -> synthesized_speech_189.wav
#   使用方法: data_deal_816_output
#
# 处理索引 190 (行 191):
#   data_deal_816_output: 0.8197
#   1_output: 0.8081
#   2_output: 0.8086
#   3_output: 0.8133
#   4_output: 0.8093
#   5_output: 0.8112
#   6_output: 0.8118
#   最高分方法: data_deal_816_output, 分数: 0.8197
#   ✓ 复制成功: synthesized_speech_190.wav -> synthesized_speech_190.wav
#   使用方法: data_deal_816_output
#
# 处理索引 191 (行 192):
#   data_deal_816_output: 0.6763
#   1_output: 0.6698
#   2_output: 0.6726
#   3_output: 0.6802
#   4_output: 0.7150
#   5_output: 0.6850
#   6_output: 0.6778
#   最高分方法: 4_output, 分数: 0.7150
#   ✓ 复制成功: synthesized_speech_191.wav -> synthesized_speech_191.wav
#   使用方法: 4_output
#
# 处理索引 192 (行 193):
#   data_deal_816_output: 0.7758
#   1_output: 0.8065
#   2_output: 0.7930
#   3_output: 0.8233
#   4_output: 0.8044
#   5_output: 0.7820
#   6_output: 0.8159
#   最高分方法: 3_output, 分数: 0.8233
#   ✓ 复制成功: synthesized_speech_192.wav -> synthesized_speech_192.wav
#   使用方法: 3_output
#
# 处理索引 193 (行 194):
#   data_deal_816_output: 0.5124
#   1_output: 0.5573
#   2_output: 0.5776
#   3_output: 0.5408
#   4_output: 0.5528
#   5_output: 0.5343
#   6_output: 0.5873
#   最高分方法: 6_output, 分数: 0.5873
#   ✓ 复制成功: synthesized_speech_193.wav -> synthesized_speech_193.wav
#   使用方法: 6_output
#
# 处理索引 194 (行 195):
#   data_deal_816_output: 0.3943
#   1_output: 0.3835
#   2_output: 0.3541
#   3_output: 0.3925
#   4_output: 0.3974
#   5_output: 0.3622
#   6_output: 0.4011
#   最高分方法: 6_output, 分数: 0.4011
#   ✓ 复制成功: synthesized_speech_194.wav -> synthesized_speech_194.wav
#   使用方法: 6_output
#
# 处理索引 195 (行 196):
#   data_deal_816_output: 0.6494
#   1_output: 0.6488
#   2_output: 0.6288
#   3_output: 0.6187
#   4_output: 0.6372
#   5_output: 0.6709
#   6_output: 0.6082
#   最高分方法: 5_output, 分数: 0.6709
#   ✓ 复制成功: synthesized_speech_195.wav -> synthesized_speech_195.wav
#   使用方法: 5_output
#
# 处理索引 196 (行 197):
#   data_deal_816_output: 0.7831
#   1_output: 0.7813
#   2_output: 0.7841
#   3_output: 0.7817
#   4_output: 0.7689
#   5_output: 0.7750
#   6_output: 0.7763
#   最高分方法: 2_output, 分数: 0.7841
#   ✓ 复制成功: synthesized_speech_196.wav -> synthesized_speech_196.wav
#   使用方法: 2_output
#
# 处理索引 197 (行 198):
#   data_deal_816_output: 0.7347
#   1_output: 0.7297
#   2_output: 0.7233
#   3_output: 0.7423
#   4_output: 0.7293
#   5_output: 0.7341
#   6_output: 0.7257
#   最高分方法: 3_output, 分数: 0.7423
#   ✓ 复制成功: synthesized_speech_197.wav -> synthesized_speech_197.wav
#   使用方法: 3_output
#
# 处理索引 198 (行 199):
#   data_deal_816_output: 0.7505
#   1_output: 0.7336
#   2_output: 0.7253
#   3_output: 0.7180
#   4_output: 0.7321
#   5_output: 0.7283
#   6_output: 0.7125
#   最高分方法: data_deal_816_output, 分数: 0.7505
#   ✓ 复制成功: synthesized_speech_198.wav -> synthesized_speech_198.wav
#   使用方法: data_deal_816_output
#
# 处理索引 199 (行 200):
#   data_deal_816_output: 0.5630
#   1_output: 0.5573
#   2_output: 0.5468
#   3_output: 0.5523
#   4_output: 0.5446
#   5_output: 0.5715
#   6_output: 0.5587
#   最高分方法: 5_output, 分数: 0.5715
#   ✓ 复制成功: synthesized_speech_199.wav -> synthesized_speech_199.wav
#   使用方法: 5_output
#
# 处理索引 200 (行 201):
#   data_deal_816_output: 0.4368
#   1_output: 0.4125
#   2_output: 0.3953
#   3_output: 0.3828
#   4_output: 0.4035
#   5_output: 0.4470
#   6_output: 0.4022
#   最高分方法: 5_output, 分数: 0.4470
#   ✓ 复制成功: synthesized_speech_200.wav -> synthesized_speech_200.wav
#   使用方法: 5_output
#
# ==================================================
# 处理完成!
# ==================================================
# 成功复制: 200 个文件
# 复制失败: 0 个文件
# 文件不存在: 0 个文件
# 所有值无效: 0 个文件
# 输出目录: ./best_audio_results/
